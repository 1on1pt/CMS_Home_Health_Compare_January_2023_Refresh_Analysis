# %%
# Import the necessary libraries and load the files needed for EDA
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.patches as mpatches
import warnings
warnings.filterwarnings("ignore")
import geopandas as gpd
from shapely.geometry import Point, Polygon
import fiona

# %% [markdown]
# ## Quality Star Rating Analysis
#
# ### Quality Star Rating Measures (7)
# * How often the home health team began their patients care in a timely manner
# * How often patients got better at walking or moving around
# * How often patients got better at getting in and out of bed
# * How often patients got better at bathing
# * How often patients breathing improved
# * How often patients got better at taking their drugs correctly by mouth
# * How often home health patients had to be admitted to the hospital

# %%
df = pd.read_csv('Resources/HH_Provider_Jan2023.csv')

# %%
# Set the below parameters so that all rows and columns would be visible
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Calculate the number of rows and columns in the dataset
df.shape
# Out:
# (11609, 64)

# %%
df.head().style.set_properties(**{'text-align': 'right'})
# Out:
# <style type="text/css">
# #T_3661c_row0_col0, #T_3661c_row0_col1, #T_3661c_row0_col2, #T_3661c_row0_col3, #T_3661c_row0_col4, #T_3661c_row0_col5, #T_3661c_row0_col6, #T_3661c_row0_col7, #T_3661c_row0_col8, #T_3661c_row0_col9, #T_3661c_row0_col10, #T_3661c_row0_col11, #T_3661c_row0_col12, #T_3661c_row0_col13, #T_3661c_row0_col14, #T_3661c_row0_col15, #T_3661c_row0_col16, #T_3661c_row0_col17, #T_3661c_row0_col18, #T_3661c_row0_col19, #T_3661c_row0_col20, #T_3661c_row0_col21, #T_3661c_row0_col22, #T_3661c_row0_col23, #T_3661c_row0_col24, #T_3661c_row0_col25, #T_3661c_row0_col26, #T_3661c_row0_col27, #T_3661c_row0_col28, #T_3661c_row0_col29, #T_3661c_row0_col30, #T_3661c_row0_col31, #T_3661c_row0_col32, #T_3661c_row0_col33, #T_3661c_row0_col34, #T_3661c_row0_col35, #T_3661c_row0_col36, #T_3661c_row0_col37, #T_3661c_row0_col38, #T_3661c_row0_col39, #T_3661c_row0_col40, #T_3661c_row0_col41, #T_3661c_row0_col42, #T_3661c_row0_col43, #T_3661c_row0_col44, #T_3661c_row0_col45, #T_3661c_row0_col46, #T_3661c_row0_col47, #T_3661c_row0_col48, #T_3661c_row0_col49, #T_3661c_row0_col50, #T_3661c_row0_col51, #T_3661c_row0_col52, #T_3661c_row0_col53, #T_3661c_row0_col54, #T_3661c_row0_col55, #T_3661c_row0_col56, #T_3661c_row0_col57, #T_3661c_row0_col58, #T_3661c_row0_col59, #T_3661c_row0_col60, #T_3661c_row0_col61, #T_3661c_row0_col62, #T_3661c_row0_col63, #T_3661c_row1_col0, #T_3661c_row1_col1, #T_3661c_row1_col2, #T_3661c_row1_col3, #T_3661c_row1_col4, #T_3661c_row1_col5, #T_3661c_row1_col6, #T_3661c_row1_col7, #T_3661c_row1_col8, #T_3661c_row1_col9, #T_3661c_row1_col10, #T_3661c_row1_col11, #T_3661c_row1_col12, #T_3661c_row1_col13, #T_3661c_row1_col14, #T_3661c_row1_col15, #T_3661c_row1_col16, #T_3661c_row1_col17, #T_3661c_row1_col18, #T_3661c_row1_col19, #T_3661c_row1_col20, #T_3661c_row1_col21, #T_3661c_row1_col22, #T_3661c_row1_col23, #T_3661c_row1_col24, #T_3661c_row1_col25, #T_3661c_row1_col26, #T_3661c_row1_col27, #T_3661c_row1_col28, #T_3661c_row1_col29, #T_3661c_row1_col30, #T_3661c_row1_col31, #T_3661c_row1_col32, #T_3661c_row1_col33, #T_3661c_row1_col34, #T_3661c_row1_col35, #T_3661c_row1_col36, #T_3661c_row1_col37, #T_3661c_row1_col38, #T_3661c_row1_col39, #T_3661c_row1_col40, #T_3661c_row1_col41, #T_3661c_row1_col42, #T_3661c_row1_col43, #T_3661c_row1_col44, #T_3661c_row1_col45, #T_3661c_row1_col46, #T_3661c_row1_col47, #T_3661c_row1_col48, #T_3661c_row1_col49, #T_3661c_row1_col50, #T_3661c_row1_col51, #T_3661c_row1_col52, #T_3661c_row1_col53, #T_3661c_row1_col54, #T_3661c_row1_col55, #T_3661c_row1_col56, #T_3661c_row1_col57, #T_3661c_row1_col58, #T_3661c_row1_col59, #T_3661c_row1_col60, #T_3661c_row1_col61, #T_3661c_row1_col62, #T_3661c_row1_col63, #T_3661c_row2_col0, #T_3661c_row2_col1, #T_3661c_row2_col2, #T_3661c_row2_col3, #T_3661c_row2_col4, #T_3661c_row2_col5, #T_3661c_row2_col6, #T_3661c_row2_col7, #T_3661c_row2_col8, #T_3661c_row2_col9, #T_3661c_row2_col10, #T_3661c_row2_col11, #T_3661c_row2_col12, #T_3661c_row2_col13, #T_3661c_row2_col14, #T_3661c_row2_col15, #T_3661c_row2_col16, #T_3661c_row2_col17, #T_3661c_row2_col18, #T_3661c_row2_col19, #T_3661c_row2_col20, #T_3661c_row2_col21, #T_3661c_row2_col22, #T_3661c_row2_col23, #T_3661c_row2_col24, #T_3661c_row2_col25, #T_3661c_row2_col26, #T_3661c_row2_col27, #T_3661c_row2_col28, #T_3661c_row2_col29, #T_3661c_row2_col30, #T_3661c_row2_col31, #T_3661c_row2_col32, #T_3661c_row2_col33, #T_3661c_row2_col34, #T_3661c_row2_col35, #T_3661c_row2_col36, #T_3661c_row2_col37, #T_3661c_row2_col38, #T_3661c_row2_col39, #T_3661c_row2_col40, #T_3661c_row2_col41, #T_3661c_row2_col42, #T_3661c_row2_col43, #T_3661c_row2_col44, #T_3661c_row2_col45, #T_3661c_row2_col46, #T_3661c_row2_col47, #T_3661c_row2_col48, #T_3661c_row2_col49, #T_3661c_row2_col50, #T_3661c_row2_col51, #T_3661c_row2_col52, #T_3661c_row2_col53, #T_3661c_row2_col54, #T_3661c_row2_col55, #T_3661c_row2_col56, #T_3661c_row2_col57, #T_3661c_row2_col58, #T_3661c_row2_col59, #T_3661c_row2_col60, #T_3661c_row2_col61, #T_3661c_row2_col62, #T_3661c_row2_col63 ...
#   text-align: right;
# }
# </style>
# <table id="T_3661c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3661c_level0_col0" class="col_heading level0 col0" >State</th>
#       <th id="T_3661c_level0_col1" class="col_heading level0 col1" >CMS Certification Number (CCN)</th>
#       <th id="T_3661c_level0_col2" class="col_heading level0 col2" >Provider Name</th>
#       <th id="T_3661c_level0_col3" class="col_heading level0 col3" >Address</th>
#       <th id="T_3661c_level0_col4" class="col_heading level0 col4" >City</th>
#       <th id="T_3661c_level0_col5" class="col_heading level0 col5" >ZIP</th>
#       <th id="T_3661c_level0_col6" class="col_heading level0 col6" >Phone</th>
#       <th id="T_3661c_level0_col7" class="col_heading level0 col7" >Type of Ownership</th>
#       <th id="T_3661c_level0_col8" class="col_heading level0 col8" >Offers Nursing Care Services</th>
#       <th id="T_3661c_level0_col9" class="col_heading level0 col9" >Offers Physical Therapy Services</th>
#       <th id="T_3661c_level0_col10" class="col_heading level0 col10" >Offers Occupational Therapy Services</th>
#       <th id="T_3661c_level0_col11" class="col_heading level0 col11" >Offers Speech Pathology Services</th>
#       <th id="T_3661c_level0_col12" class="col_heading level0 col12" >Offers Medical

# %%
df.tail().style.set_properties(**{'text-align': 'right'})
# Out:
# <style type="text/css">
# #T_a2c76_row0_col0, #T_a2c76_row0_col1, #T_a2c76_row0_col2, #T_a2c76_row0_col3, #T_a2c76_row0_col4, #T_a2c76_row0_col5, #T_a2c76_row0_col6, #T_a2c76_row0_col7, #T_a2c76_row0_col8, #T_a2c76_row0_col9, #T_a2c76_row0_col10, #T_a2c76_row0_col11, #T_a2c76_row0_col12, #T_a2c76_row0_col13, #T_a2c76_row0_col14, #T_a2c76_row0_col15, #T_a2c76_row0_col16, #T_a2c76_row0_col17, #T_a2c76_row0_col18, #T_a2c76_row0_col19, #T_a2c76_row0_col20, #T_a2c76_row0_col21, #T_a2c76_row0_col22, #T_a2c76_row0_col23, #T_a2c76_row0_col24, #T_a2c76_row0_col25, #T_a2c76_row0_col26, #T_a2c76_row0_col27, #T_a2c76_row0_col28, #T_a2c76_row0_col29, #T_a2c76_row0_col30, #T_a2c76_row0_col31, #T_a2c76_row0_col32, #T_a2c76_row0_col33, #T_a2c76_row0_col34, #T_a2c76_row0_col35, #T_a2c76_row0_col36, #T_a2c76_row0_col37, #T_a2c76_row0_col38, #T_a2c76_row0_col39, #T_a2c76_row0_col40, #T_a2c76_row0_col41, #T_a2c76_row0_col42, #T_a2c76_row0_col43, #T_a2c76_row0_col44, #T_a2c76_row0_col45, #T_a2c76_row0_col46, #T_a2c76_row0_col47, #T_a2c76_row0_col48, #T_a2c76_row0_col49, #T_a2c76_row0_col50, #T_a2c76_row0_col51, #T_a2c76_row0_col52, #T_a2c76_row0_col53, #T_a2c76_row0_col54, #T_a2c76_row0_col55, #T_a2c76_row0_col56, #T_a2c76_row0_col57, #T_a2c76_row0_col58, #T_a2c76_row0_col59, #T_a2c76_row0_col60, #T_a2c76_row0_col61, #T_a2c76_row0_col62, #T_a2c76_row0_col63, #T_a2c76_row1_col0, #T_a2c76_row1_col1, #T_a2c76_row1_col2, #T_a2c76_row1_col3, #T_a2c76_row1_col4, #T_a2c76_row1_col5, #T_a2c76_row1_col6, #T_a2c76_row1_col7, #T_a2c76_row1_col8, #T_a2c76_row1_col9, #T_a2c76_row1_col10, #T_a2c76_row1_col11, #T_a2c76_row1_col12, #T_a2c76_row1_col13, #T_a2c76_row1_col14, #T_a2c76_row1_col15, #T_a2c76_row1_col16, #T_a2c76_row1_col17, #T_a2c76_row1_col18, #T_a2c76_row1_col19, #T_a2c76_row1_col20, #T_a2c76_row1_col21, #T_a2c76_row1_col22, #T_a2c76_row1_col23, #T_a2c76_row1_col24, #T_a2c76_row1_col25, #T_a2c76_row1_col26, #T_a2c76_row1_col27, #T_a2c76_row1_col28, #T_a2c76_row1_col29, #T_a2c76_row1_col30, #T_a2c76_row1_col31, #T_a2c76_row1_col32, #T_a2c76_row1_col33, #T_a2c76_row1_col34, #T_a2c76_row1_col35, #T_a2c76_row1_col36, #T_a2c76_row1_col37, #T_a2c76_row1_col38, #T_a2c76_row1_col39, #T_a2c76_row1_col40, #T_a2c76_row1_col41, #T_a2c76_row1_col42, #T_a2c76_row1_col43, #T_a2c76_row1_col44, #T_a2c76_row1_col45, #T_a2c76_row1_col46, #T_a2c76_row1_col47, #T_a2c76_row1_col48, #T_a2c76_row1_col49, #T_a2c76_row1_col50, #T_a2c76_row1_col51, #T_a2c76_row1_col52, #T_a2c76_row1_col53, #T_a2c76_row1_col54, #T_a2c76_row1_col55, #T_a2c76_row1_col56, #T_a2c76_row1_col57, #T_a2c76_row1_col58, #T_a2c76_row1_col59, #T_a2c76_row1_col60, #T_a2c76_row1_col61, #T_a2c76_row1_col62, #T_a2c76_row1_col63, #T_a2c76_row2_col0, #T_a2c76_row2_col1, #T_a2c76_row2_col2, #T_a2c76_row2_col3, #T_a2c76_row2_col4, #T_a2c76_row2_col5, #T_a2c76_row2_col6, #T_a2c76_row2_col7, #T_a2c76_row2_col8, #T_a2c76_row2_col9, #T_a2c76_row2_col10, #T_a2c76_row2_col11, #T_a2c76_row2_col12, #T_a2c76_row2_col13, #T_a2c76_row2_col14, #T_a2c76_row2_col15, #T_a2c76_row2_col16, #T_a2c76_row2_col17, #T_a2c76_row2_col18, #T_a2c76_row2_col19, #T_a2c76_row2_col20, #T_a2c76_row2_col21, #T_a2c76_row2_col22, #T_a2c76_row2_col23, #T_a2c76_row2_col24, #T_a2c76_row2_col25, #T_a2c76_row2_col26, #T_a2c76_row2_col27, #T_a2c76_row2_col28, #T_a2c76_row2_col29, #T_a2c76_row2_col30, #T_a2c76_row2_col31, #T_a2c76_row2_col32, #T_a2c76_row2_col33, #T_a2c76_row2_col34, #T_a2c76_row2_col35, #T_a2c76_row2_col36, #T_a2c76_row2_col37, #T_a2c76_row2_col38, #T_a2c76_row2_col39, #T_a2c76_row2_col40, #T_a2c76_row2_col41, #T_a2c76_row2_col42, #T_a2c76_row2_col43, #T_a2c76_row2_col44, #T_a2c76_row2_col45, #T_a2c76_row2_col46, #T_a2c76_row2_col47, #T_a2c76_row2_col48, #T_a2c76_row2_col49, #T_a2c76_row2_col50, #T_a2c76_row2_col51, #T_a2c76_row2_col52, #T_a2c76_row2_col53, #T_a2c76_row2_col54, #T_a2c76_row2_col55, #T_a2c76_row2_col56, #T_a2c76_row2_col57, #T_a2c76_row2_col58, #T_a2c76_row2_col59, #T_a2c76_row2_col60, #T_a2c76_row2_col61, #T_a2c76_row2_col62, #T_a2c76_row2_col63 ...
#   text-align: right;
# }
# </style>
# <table id="T_a2c76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2c76_level0_col0" class="col_heading level0 col0" >State</th>
#       <th id="T_a2c76_level0_col1" class="col_heading level0 col1" >CMS Certification Number (CCN)</th>
#       <th id="T_a2c76_level0_col2" class="col_heading level0 col2" >Provider Name</th>
#       <th id="T_a2c76_level0_col3" class="col_heading level0 col3" >Address</th>
#       <th id="T_a2c76_level0_col4" class="col_heading level0 col4" >City</th>
#       <th id="T_a2c76_level0_col5" class="col_heading level0 col5" >ZIP</th>
#       <th id="T_a2c76_level0_col6" class="col_heading level0 col6" >Phone</th>
#       <th id="T_a2c76_level0_col7" class="col_heading level0 col7" >Type of Ownership</th>
#       <th id="T_a2c76_level0_col8" class="col_heading level0 col8" >Offers Nursing Care Services</th>
#       <th id="T_a2c76_level0_col9" class="col_heading level0 col9" >Offers Physical Therapy Services</th>
#       <th id="T_a2c76_level0_col10" class="col_heading level0 col10" >Offers Occupational Therapy Services</th>
#       <th id="T_a2c76_level0_col11" class="col_heading level0 col11" >Offers Speech Pathology Services</th>
#       <th id="T_a2c76_level0_col12" class="col_heading level0 col12" >Offers Medical

# %% [markdown]
# ### Remove cells that will not be related to further analysis

# %%
columns_to_drop = ['Footnote for quality of patient care star rating',
                  'Footnote for how often the home health team began their patients care in a timely manner',
                  'Footnote for how often the home health team taught patients (or their family caregivers) about their drugs',
                  'Footnote for how often the home health team determined whether patients received a flu shot for the current flu season',
                  'Footnote for how often patients got better at walking or moving around',
                  'Footnote for how often patients got better at getting in and out of bed',
                  'Footnote for how often patients got better at bathing',
                  'Footnote for how often patients breathing improved',
                  'Footnote for how often patients got better at taking their drugs correctly by mouth',
                  'Footnote for how often home health patients had to be admitted to the hospital',
                  'Footnote for how often patients receiving home health care needed urgent, unplanned care in the ER without being admitted',
                  'Footnote Changes in skin integrity post-acute care: pressure ulcer/injury',
                  'Footnote for how often physician-recommended actions to address medication issues were completely timely',
                  'Footnote for Percent of Residents Experiencing One or More Falls with Major Injury',
                  'Footnote for Application of Percent of Long Term Care Hospital Patients with an Admission and Discharge Functional Assessment and a Care Plan that Addresses Function',
                  'Footnote for DTC Risk-Standardized Rate',
                  'Footnote for PPR Risk-Standardized Rate',
                  'Footnote for how much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally']

df.drop(columns = columns_to_drop, inplace = True)

# %%
df.shape
# Out:
# (11609, 46)

# %%
df.head().style.set_properties(**{'text-align': 'right'})
# Out:
# <style type="text/css">
# #T_374cc_row0_col0, #T_374cc_row0_col1, #T_374cc_row0_col2, #T_374cc_row0_col3, #T_374cc_row0_col4, #T_374cc_row0_col5, #T_374cc_row0_col6, #T_374cc_row0_col7, #T_374cc_row0_col8, #T_374cc_row0_col9, #T_374cc_row0_col10, #T_374cc_row0_col11, #T_374cc_row0_col12, #T_374cc_row0_col13, #T_374cc_row0_col14, #T_374cc_row0_col15, #T_374cc_row0_col16, #T_374cc_row0_col17, #T_374cc_row0_col18, #T_374cc_row0_col19, #T_374cc_row0_col20, #T_374cc_row0_col21, #T_374cc_row0_col22, #T_374cc_row0_col23, #T_374cc_row0_col24, #T_374cc_row0_col25, #T_374cc_row0_col26, #T_374cc_row0_col27, #T_374cc_row0_col28, #T_374cc_row0_col29, #T_374cc_row0_col30, #T_374cc_row0_col31, #T_374cc_row0_col32, #T_374cc_row0_col33, #T_374cc_row0_col34, #T_374cc_row0_col35, #T_374cc_row0_col36, #T_374cc_row0_col37, #T_374cc_row0_col38, #T_374cc_row0_col39, #T_374cc_row0_col40, #T_374cc_row0_col41, #T_374cc_row0_col42, #T_374cc_row0_col43, #T_374cc_row0_col44, #T_374cc_row0_col45, #T_374cc_row1_col0, #T_374cc_row1_col1, #T_374cc_row1_col2, #T_374cc_row1_col3, #T_374cc_row1_col4, #T_374cc_row1_col5, #T_374cc_row1_col6, #T_374cc_row1_col7, #T_374cc_row1_col8, #T_374cc_row1_col9, #T_374cc_row1_col10, #T_374cc_row1_col11, #T_374cc_row1_col12, #T_374cc_row1_col13, #T_374cc_row1_col14, #T_374cc_row1_col15, #T_374cc_row1_col16, #T_374cc_row1_col17, #T_374cc_row1_col18, #T_374cc_row1_col19, #T_374cc_row1_col20, #T_374cc_row1_col21, #T_374cc_row1_col22, #T_374cc_row1_col23, #T_374cc_row1_col24, #T_374cc_row1_col25, #T_374cc_row1_col26, #T_374cc_row1_col27, #T_374cc_row1_col28, #T_374cc_row1_col29, #T_374cc_row1_col30, #T_374cc_row1_col31, #T_374cc_row1_col32, #T_374cc_row1_col33, #T_374cc_row1_col34, #T_374cc_row1_col35, #T_374cc_row1_col36, #T_374cc_row1_col37, #T_374cc_row1_col38, #T_374cc_row1_col39, #T_374cc_row1_col40, #T_374cc_row1_col41, #T_374cc_row1_col42, #T_374cc_row1_col43, #T_374cc_row1_col44, #T_374cc_row1_col45, #T_374cc_row2_col0, #T_374cc_row2_col1, #T_374cc_row2_col2, #T_374cc_row2_col3, #T_374cc_row2_col4, #T_374cc_row2_col5, #T_374cc_row2_col6, #T_374cc_row2_col7, #T_374cc_row2_col8, #T_374cc_row2_col9, #T_374cc_row2_col10, #T_374cc_row2_col11, #T_374cc_row2_col12, #T_374cc_row2_col13, #T_374cc_row2_col14, #T_374cc_row2_col15, #T_374cc_row2_col16, #T_374cc_row2_col17, #T_374cc_row2_col18, #T_374cc_row2_col19, #T_374cc_row2_col20, #T_374cc_row2_col21, #T_374cc_row2_col22, #T_374cc_row2_col23, #T_374cc_row2_col24, #T_374cc_row2_col25, #T_374cc_row2_col26, #T_374cc_row2_col27, #T_374cc_row2_col28, #T_374cc_row2_col29, #T_374cc_row2_col30, #T_374cc_row2_col31, #T_374cc_row2_col32, #T_374cc_row2_col33, #T_374cc_row2_col34, #T_374cc_row2_col35, #T_374cc_row2_col36, #T_374cc_row2_col37, #T_374cc_row2_col38, #T_374cc_row2_col39, #T_374cc_row2_col40, #T_374cc_row2_col41, #T_374cc_row2_col42, #T_374cc_row2_col43, #T_374cc_row2_col44, #T_374cc_row2_col45, #T_374cc_row3_col0, #T_374cc_row3_col1, #T_374cc_row3_col2, #T_374cc_row3_col3, #T_374cc_row3_col4, #T_374cc_row3_col5, #T_374cc_row3_col6, #T_374cc_row3_col7, #T_374cc_row3_col8, #T_374cc_row3_col9, #T_374cc_row3_col10, #T_374cc_row3_col11, #T_374cc_row3_col12, #T_374cc_row3_col13, #T_374cc_row3_col14, #T_374cc_row3_col15, #T_374cc_row3_col16, #T_374cc_row3_col17, #T_374cc_row3_col18, #T_374cc_row3_col19, #T_374cc_row3_col20, #T_374cc_row3_col21, #T_374cc_row3_col22, #T_374cc_row3_col23, #T_374cc_row3_col24, #T_374cc_row3_col25, #T_374cc_row3_col26, #T_374cc_row3_col27, #T_374cc_row3_col28, #T_374cc_row3_col29, #T_374cc_row3_col30, #T_374cc_row3_col31, #T_374cc_row3_col32, #T_374cc_row3_col33, #T_374cc_row3_col34, #T_374cc_row3_col35, #T_374cc_row3_col36, #T_374cc_row3_col37, #T_374cc_row3_col38, #T_374cc_row3_col39, #T_374cc_row3_col40, #T_374cc_row3_col41, #T_374cc_row3_col42, #T_374cc_row3_col43, #T_374cc_row3_col44, #T_374cc_row3_col45, #T_374cc_row4_col0, #T_374cc_row4_col1, #T_374cc_row4_col2, #T_374cc_row4_col3, #T_374cc_row4_col4, #T_374cc_row4_col5, #T_374cc_row4_col6, #T_374cc_row4_col7, #T_374cc_row4_co ...
#   text-align: right;
# }
# </style>
# <table id="T_374cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_374cc_level0_col0" class="col_heading level0 col0" >State</th>
#       <th id="T_374cc_level0_col1" class="col_heading level0 col1" >CMS Certification Number (CCN)</th>
#       <th id="T_374cc_level0_col2" class="col_heading level0 col2" >Provider Name</th>
#       <th id="T_374cc_level0_col3" class="col_heading level0 col3" >Address</th>
#       <th id="T_374cc_level0_col4" class="col_heading level0 col4" >City</th>
#       <th id="T_374cc_level0_col5" class="col_heading level0 col5" >ZIP</th>
#       <th id="T_374cc_level0_col6" class="col_heading level0 col6" >Phone</th>
#       <th id="T_374cc_level0_col7" class="col_heading level0 col7" >Type of Ownership</th>
#       <th id="T_374cc_level0_col8" class="col_heading level0 col8" >Offers Nursing Care Services</th>
#       <th id="T_374cc_level0_col9" class="col_heading level0 col9" >Offers Physical Therapy Services</th>
#       <th id="T_374cc_level0_col10" class="col_heading level0 col10" >Offers Occupational Therapy Services</th>
#       <th id="T_374cc_level0_col11" class="col_heading level0 col11" >Offers Speech Pathology Services</th>
#       <th id="T_374cc_level0_col12" class="col_heading level0 col12" >Offers Medical Social Services</th>
#       <th id="T_374cc_level0_col13" class="col_heading level0 col13" >Offers Home Health Aide Services</th>
#       <th id="T_374cc_level0_col14" class="col_heading level0 col14" >Date Certified</th>
#       <th id="T_374cc_level0_col15" class="col_heading level0 col15" >Quality of patient care star rating</th>
#       <th id="T_374cc_level0_col16" class="col_heading level0 col16" >How often the home health team began their patients care in a timely manner</th>
#       <th id="T_374cc_level0_col17" class="col_heading level0 col17" >How often the home health team taught patients (or their family caregivers) about their drugs</th>
#       <th id="T_374cc_level0_col18" class="col_heading level0 col18" >How often the home health team determined whether patients received a flu shot for the current flu season</th>
#       <th id="T_374cc_level0_col19" class="col_heading level0 col19" >How often patients got better at walking or moving around</th>
#       <th id="T_374cc_level0_col20" class="col_heading level0 col20" >How often patients got better at getting in and out of bed</th>
#       <th id="T_374cc_level0_col21" class="col_heading level0 col21" >How often patients got better at bathing</th>
#       <th id="T_374cc_level0_col22" class="col_heading level0 col22" >How often patients breathing improved</th>
#       <th id="T_374cc_level0_col23" class="col_heading level0 col23" >How often patients got better at taking their drugs correctly by mouth</th>
#       <th id="T_374cc_level0_col24" class="col_heading level0 col24" >How often home health patients had to be admitted to the hospital</th>
#       <th id="T_374cc_level0_col25" class="col_heading level0 col25" >How often patients receiving home health care needed urgent, unplanned care in the ER without being admitted</th>
#       <th id="T_374cc_level0_col26" class="col_heading level0 col26" >Changes in skin integr

# %%
df.tail().style.set_properties(**{'text-align': 'right'})
# Out:
# <style type="text/css">
# #T_063cb_row0_col0, #T_063cb_row0_col1, #T_063cb_row0_col2, #T_063cb_row0_col3, #T_063cb_row0_col4, #T_063cb_row0_col5, #T_063cb_row0_col6, #T_063cb_row0_col7, #T_063cb_row0_col8, #T_063cb_row0_col9, #T_063cb_row0_col10, #T_063cb_row0_col11, #T_063cb_row0_col12, #T_063cb_row0_col13, #T_063cb_row0_col14, #T_063cb_row0_col15, #T_063cb_row0_col16, #T_063cb_row0_col17, #T_063cb_row0_col18, #T_063cb_row0_col19, #T_063cb_row0_col20, #T_063cb_row0_col21, #T_063cb_row0_col22, #T_063cb_row0_col23, #T_063cb_row0_col24, #T_063cb_row0_col25, #T_063cb_row0_col26, #T_063cb_row0_col27, #T_063cb_row0_col28, #T_063cb_row0_col29, #T_063cb_row0_col30, #T_063cb_row0_col31, #T_063cb_row0_col32, #T_063cb_row0_col33, #T_063cb_row0_col34, #T_063cb_row0_col35, #T_063cb_row0_col36, #T_063cb_row0_col37, #T_063cb_row0_col38, #T_063cb_row0_col39, #T_063cb_row0_col40, #T_063cb_row0_col41, #T_063cb_row0_col42, #T_063cb_row0_col43, #T_063cb_row0_col44, #T_063cb_row0_col45, #T_063cb_row1_col0, #T_063cb_row1_col1, #T_063cb_row1_col2, #T_063cb_row1_col3, #T_063cb_row1_col4, #T_063cb_row1_col5, #T_063cb_row1_col6, #T_063cb_row1_col7, #T_063cb_row1_col8, #T_063cb_row1_col9, #T_063cb_row1_col10, #T_063cb_row1_col11, #T_063cb_row1_col12, #T_063cb_row1_col13, #T_063cb_row1_col14, #T_063cb_row1_col15, #T_063cb_row1_col16, #T_063cb_row1_col17, #T_063cb_row1_col18, #T_063cb_row1_col19, #T_063cb_row1_col20, #T_063cb_row1_col21, #T_063cb_row1_col22, #T_063cb_row1_col23, #T_063cb_row1_col24, #T_063cb_row1_col25, #T_063cb_row1_col26, #T_063cb_row1_col27, #T_063cb_row1_col28, #T_063cb_row1_col29, #T_063cb_row1_col30, #T_063cb_row1_col31, #T_063cb_row1_col32, #T_063cb_row1_col33, #T_063cb_row1_col34, #T_063cb_row1_col35, #T_063cb_row1_col36, #T_063cb_row1_col37, #T_063cb_row1_col38, #T_063cb_row1_col39, #T_063cb_row1_col40, #T_063cb_row1_col41, #T_063cb_row1_col42, #T_063cb_row1_col43, #T_063cb_row1_col44, #T_063cb_row1_col45, #T_063cb_row2_col0, #T_063cb_row2_col1, #T_063cb_row2_col2, #T_063cb_row2_col3, #T_063cb_row2_col4, #T_063cb_row2_col5, #T_063cb_row2_col6, #T_063cb_row2_col7, #T_063cb_row2_col8, #T_063cb_row2_col9, #T_063cb_row2_col10, #T_063cb_row2_col11, #T_063cb_row2_col12, #T_063cb_row2_col13, #T_063cb_row2_col14, #T_063cb_row2_col15, #T_063cb_row2_col16, #T_063cb_row2_col17, #T_063cb_row2_col18, #T_063cb_row2_col19, #T_063cb_row2_col20, #T_063cb_row2_col21, #T_063cb_row2_col22, #T_063cb_row2_col23, #T_063cb_row2_col24, #T_063cb_row2_col25, #T_063cb_row2_col26, #T_063cb_row2_col27, #T_063cb_row2_col28, #T_063cb_row2_col29, #T_063cb_row2_col30, #T_063cb_row2_col31, #T_063cb_row2_col32, #T_063cb_row2_col33, #T_063cb_row2_col34, #T_063cb_row2_col35, #T_063cb_row2_col36, #T_063cb_row2_col37, #T_063cb_row2_col38, #T_063cb_row2_col39, #T_063cb_row2_col40, #T_063cb_row2_col41, #T_063cb_row2_col42, #T_063cb_row2_col43, #T_063cb_row2_col44, #T_063cb_row2_col45, #T_063cb_row3_col0, #T_063cb_row3_col1, #T_063cb_row3_col2, #T_063cb_row3_col3, #T_063cb_row3_col4, #T_063cb_row3_col5, #T_063cb_row3_col6, #T_063cb_row3_col7, #T_063cb_row3_col8, #T_063cb_row3_col9, #T_063cb_row3_col10, #T_063cb_row3_col11, #T_063cb_row3_col12, #T_063cb_row3_col13, #T_063cb_row3_col14, #T_063cb_row3_col15, #T_063cb_row3_col16, #T_063cb_row3_col17, #T_063cb_row3_col18, #T_063cb_row3_col19, #T_063cb_row3_col20, #T_063cb_row3_col21, #T_063cb_row3_col22, #T_063cb_row3_col23, #T_063cb_row3_col24, #T_063cb_row3_col25, #T_063cb_row3_col26, #T_063cb_row3_col27, #T_063cb_row3_col28, #T_063cb_row3_col29, #T_063cb_row3_col30, #T_063cb_row3_col31, #T_063cb_row3_col32, #T_063cb_row3_col33, #T_063cb_row3_col34, #T_063cb_row3_col35, #T_063cb_row3_col36, #T_063cb_row3_col37, #T_063cb_row3_col38, #T_063cb_row3_col39, #T_063cb_row3_col40, #T_063cb_row3_col41, #T_063cb_row3_col42, #T_063cb_row3_col43, #T_063cb_row3_col44, #T_063cb_row3_col45, #T_063cb_row4_col0, #T_063cb_row4_col1, #T_063cb_row4_col2, #T_063cb_row4_col3, #T_063cb_row4_col4, #T_063cb_row4_col5, #T_063cb_row4_col6, #T_063cb_row4_col7, #T_063cb_row4_co ...
#   text-align: right;
# }
# </style>
# <table id="T_063cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_063cb_level0_col0" class="col_heading level0 col0" >State</th>
#       <th id="T_063cb_level0_col1" class="col_heading level0 col1" >CMS Certification Number (CCN)</th>
#       <th id="T_063cb_level0_col2" class="col_heading level0 col2" >Provider Name</th>
#       <th id="T_063cb_level0_col3" class="col_heading level0 col3" >Address</th>
#       <th id="T_063cb_level0_col4" class="col_heading level0 col4" >City</th>
#       <th id="T_063cb_level0_col5" class="col_heading level0 col5" >ZIP</th>
#       <th id="T_063cb_level0_col6" class="col_heading level0 col6" >Phone</th>
#       <th id="T_063cb_level0_col7" class="col_heading level0 col7" >Type of Ownership</th>
#       <th id="T_063cb_level0_col8" class="col_heading level0 col8" >Offers Nursing Care Services</th>
#       <th id="T_063cb_level0_col9" class="col_heading level0 col9" >Offers Physical Therapy Services</th>
#       <th id="T_063cb_level0_col10" class="col_heading level0 col10" >Offers Occupational Therapy Services</th>
#       <th id="T_063cb_level0_col11" class="col_heading level0 col11" >Offers Speech Pathology Services</th>
#       <th id="T_063cb_level0_col12" class="col_heading level0 col12" >Offers Medical Social Services</th>
#       <th id="T_063cb_level0_col13" class="col_heading level0 col13" >Offers Home Health Aide Services</th>
#       <th id="T_063cb_level0_col14" class="col_heading level0 col14" >Date Certified</th>
#       <th id="T_063cb_level0_col15" class="col_heading level0 col15" >Quality of patient care star rating</th>
#       <th id="T_063cb_level0_col16" class="col_heading level0 col16" >How often the home health team began their patients care in a timely manner</th>
#       <th id="T_063cb_level0_col17" class="col_heading level0 col17" >How often the home health team taught patients (or their family caregivers) about their drugs</th>
#       <th id="T_063cb_level0_col18" class="col_heading level0 col18" >How often the home health team determined whether patients received a flu shot for the current flu season</th>
#       <th id="T_063cb_level0_col19" class="col_heading level0 col19" >How often patients got better at walking or moving around</th>
#       <th id="T_063cb_level0_col20" class="col_heading level0 col20" >How often patients got better at getting in and out of bed</th>
#       <th id="T_063cb_level0_col21" class="col_heading level0 col21" >How often patients got better at bathing</th>
#       <th id="T_063cb_level0_col22" class="col_heading level0 col22" >How often patients breathing improved</th>
#       <th id="T_063cb_level0_col23" class="col_heading level0 col23" >How often patients got better at taking their drugs correctly by mouth</th>
#       <th id="T_063cb_level0_col24" class="col_heading level0 col24" >How often home health patients had to be admitted to the hospital</th>
#       <th id="T_063cb_level0_col25" class="col_heading level0 col25" >How often patients receiving home health care needed urgent, unplanned care in the ER without being admitted</th>
#       <th id="T_063cb_level0_col26" class="col_heading level0 col26" >Changes in skin integr

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11609 entries, 0 to 11608
# Data columns (total 46 columns):
#  #   Column                                                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                                                    --------------  -----
#  0   State                                                                                                                                                     11609 non-null  object
#  1   CMS Certification Number (CCN)                                                                                                                            11609 non-null  int64
#  2   Provider Name                                                                                                                                             11609 non-null  object
#  3   Address                                                                                                                                                   11609 non-null  object
#  4   City                                                                                                                                                      11609 non-null  object
#  5   ZIP                                                                                                                                                       11609 non-null  int64
#  6   Phone                                                                                                                                                     10948 non-null  float64
#  7   Type of Ownership                                                                                                                                         11609 non-null  object
#  8   Offers Nursing Care Services                                                                                                                              11609 non-null  object
#  9   Offers Physical Therapy Services                                                                                                                          11609 non-null  object
#  10  Offers Occupational Therapy Services                                                                                                                      11609 non-null  object
#  11  Offers Speech Pathology Services                                                                                                                          11609 non-null  object
#  12  Offers Medical Social Services                                                                                                                            11609 non-null  object
#  13  Offers Home Health Aide Services                                                                                                                          11609 non-null  object
#  14  Date Certified                                                                                                                                            11609 non-null  object
#  15  Quality of patient care star rating                                                                                                                       7786 non-null   float64
#  16  How often the home health team began their patients care in a timely manner                                                                               8419 non-null   float64
#  17  How often the home health team taught patients (or their family caregivers) about their drugs                                                             8399 non-null   float64
#  18  How often the home health team determined whether patients received a flu shot for the current flu season                                                 8075 non-null   float64
#  19  How often patients got better at walking or moving around                                                                                                 7846 non-null   float64
#  20  How often patients got better at getting in and out of bed                                                                                                7816 non-null   float64
#  21  How often patients got better at bathing                                                                                                                  7869 non-null   float64
#  22  How often patients breathing improved                                                                                                                     7674 non-null   float64
#  23  How often patients got better at taking their drugs correctly by mouth                                                                                    7739 non-null   float64
#  24  How often home health patients had to be admitted to the hospital                                                                                         6861 non-null   float64
#  25  How often patients receiving home health care needed urgent, unplanned care in the ER without being admitted                                              6861 non-null   float64
#  26  Changes in skin integrity post-acute care: pressure ulcer/injury                                                                                          7915 non-null   float64
#  27  How often physician-recommended actions to address medication issues were completely timely                                                               8423 non-null   float64
#  28  Percent of Residents Experiencing One or More Falls with Major Injury                                                                                     8407 non-null   float64
#  29  Application of Percent of Long Term Care Hospital Patients with an Admission and Discharge Functional Assessment and a Care Plan that Addresses Function  8423 non-null   float64
#  30  DTC Numerator                                                                                                                                             7248 non-null   float64
#  31  DTC Denominator                                                                                                                                           9249 non-null   float64
#  32  DTC Observed Rate                                                                                                                                         7248 non-null   float64
#  33  DTC Risk-Standardized Rate                                                                                                                                7248 non-null   float64
#  34  DTC Risk-Standardized Rate (Lower Limit)                                                                                                                  7248 non-null   float64
#  35  DTC Risk-Standardized Rate (Upper Limit)                                                                                                                  7248 non-null   float64
#  36  DTC Performance Categorization                                                                                                                            9249 non-null   object
#  37  PPR Numerator                                                                                                                                             6290 non-null   float64
#  38  PPR Denominator                                                                                                                                           8983 non-null   float64
#  39  PPR Observed Rate                                                                                                                                         6290 non-null   float64
#  40  PPR Risk-Standardized Rate                                                                                                                                6290 non-null   float64
#  41  PPR Risk-Standardized Rate (Lower Limit)                                                                                                                  6290 non-null   float64
#  42  PPR Risk-Standardized Rate (Upper Limit)                                                                                                                  6290 non-null   float64
#  43  PPR Performance Categorization                                                                                                                            8983 non-null   object
#  44  How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally                               8393 non-null   float64
#  45  No. of episodes to calc how much Medicare spends per episode of care at agency, compared to spending at all agencies (national)                           9414 non-null   float64
# dtypes: float64(30), int64(2), object(14)
# memory usage: 4.1+ MB

# %%
df.describe().style.set_properties(**{'text-align': 'right'})
# Out:
# <style type="text/css">
# #T_d07e0_row0_col0, #T_d07e0_row0_col1, #T_d07e0_row0_col2, #T_d07e0_row0_col3, #T_d07e0_row0_col4, #T_d07e0_row0_col5, #T_d07e0_row0_col6, #T_d07e0_row0_col7, #T_d07e0_row0_col8, #T_d07e0_row0_col9, #T_d07e0_row0_col10, #T_d07e0_row0_col11, #T_d07e0_row0_col12, #T_d07e0_row0_col13, #T_d07e0_row0_col14, #T_d07e0_row0_col15, #T_d07e0_row0_col16, #T_d07e0_row0_col17, #T_d07e0_row0_col18, #T_d07e0_row0_col19, #T_d07e0_row0_col20, #T_d07e0_row0_col21, #T_d07e0_row0_col22, #T_d07e0_row0_col23, #T_d07e0_row0_col24, #T_d07e0_row0_col25, #T_d07e0_row0_col26, #T_d07e0_row0_col27, #T_d07e0_row0_col28, #T_d07e0_row0_col29, #T_d07e0_row0_col30, #T_d07e0_row0_col31, #T_d07e0_row1_col0, #T_d07e0_row1_col1, #T_d07e0_row1_col2, #T_d07e0_row1_col3, #T_d07e0_row1_col4, #T_d07e0_row1_col5, #T_d07e0_row1_col6, #T_d07e0_row1_col7, #T_d07e0_row1_col8, #T_d07e0_row1_col9, #T_d07e0_row1_col10, #T_d07e0_row1_col11, #T_d07e0_row1_col12, #T_d07e0_row1_col13, #T_d07e0_row1_col14, #T_d07e0_row1_col15, #T_d07e0_row1_col16, #T_d07e0_row1_col17, #T_d07e0_row1_col18, #T_d07e0_row1_col19, #T_d07e0_row1_col20, #T_d07e0_row1_col21, #T_d07e0_row1_col22, #T_d07e0_row1_col23, #T_d07e0_row1_col24, #T_d07e0_row1_col25, #T_d07e0_row1_col26, #T_d07e0_row1_col27, #T_d07e0_row1_col28, #T_d07e0_row1_col29, #T_d07e0_row1_col30, #T_d07e0_row1_col31, #T_d07e0_row2_col0, #T_d07e0_row2_col1, #T_d07e0_row2_col2, #T_d07e0_row2_col3, #T_d07e0_row2_col4, #T_d07e0_row2_col5, #T_d07e0_row2_col6, #T_d07e0_row2_col7, #T_d07e0_row2_col8, #T_d07e0_row2_col9, #T_d07e0_row2_col10, #T_d07e0_row2_col11, #T_d07e0_row2_col12, #T_d07e0_row2_col13, #T_d07e0_row2_col14, #T_d07e0_row2_col15, #T_d07e0_row2_col16, #T_d07e0_row2_col17, #T_d07e0_row2_col18, #T_d07e0_row2_col19, #T_d07e0_row2_col20, #T_d07e0_row2_col21, #T_d07e0_row2_col22, #T_d07e0_row2_col23, #T_d07e0_row2_col24, #T_d07e0_row2_col25, #T_d07e0_row2_col26, #T_d07e0_row2_col27, #T_d07e0_row2_col28, #T_d07e0_row2_col29, #T_d07e0_row2_col30, #T_d07e0_row2_col31, #T_d07e0_row3_col0, #T_d07e0_row3_col1, #T_d07e0_row3_col2, #T_d07e0_row3_col3, #T_d07e0_row3_col4, #T_d07e0_row3_col5, #T_d07e0_row3_col6, #T_d07e0_row3_col7, #T_d07e0_row3_col8, #T_d07e0_row3_col9, #T_d07e0_row3_col10, #T_d07e0_row3_col11, #T_d07e0_row3_col12, #T_d07e0_row3_col13, #T_d07e0_row3_col14, #T_d07e0_row3_col15, #T_d07e0_row3_col16, #T_d07e0_row3_col17, #T_d07e0_row3_col18, #T_d07e0_row3_col19, #T_d07e0_row3_col20, #T_d07e0_row3_col21, #T_d07e0_row3_col22, #T_d07e0_row3_col23, #T_d07e0_row3_col24, #T_d07e0_row3_col25, #T_d07e0_row3_col26, #T_d07e0_row3_col27, #T_d07e0_row3_col28, #T_d07e0_row3_col29, #T_d07e0_row3_col30, #T_d07e0_row3_col31, #T_d07e0_row4_col0, #T_d07e0_row4_col1, #T_d07e0_row4_col2, #T_d07e0_row4_col3, #T_d07e0_row4_col4, #T_d07e0_row4_col5, #T_d07e0_row4_col6, #T_d07e0_row4_col7, #T_d07e0_row4_col8, #T_d07e0_row4_col9, #T_d07e0_row4_col10, #T_d07e0_row4_col11, #T_d07e0_row4_col12, #T_d07e0_row4_col13, #T_d07e0_row4_col14, #T_d07e0_row4_col15, #T_d07e0_row4_col16, #T_d07e0_row4_col17, #T_d07e0_row4_col18, #T_d07e0_row4_col19, #T_d07e0_row4_col20, #T_d07e0_row4_col21, #T_d07e0_row4_col22, #T_d07e0_row4_col23, #T_d07e0_row4_col24, #T_d07e0_row4_col25, #T_d07e0_row4_col26, #T_d07e0_row4_col27, #T_d07e0_row4_col28, #T_d07e0_row4_col29, #T_d07e0_row4_col30, #T_d07e0_row4_col31, #T_d07e0_row5_col0, #T_d07e0_row5_col1, #T_d07e0_row5_col2, #T_d07e0_row5_col3, #T_d07e0_row5_col4, #T_d07e0_row5_col5, #T_d07e0_row5_col6, #T_d07e0_row5_col7, #T_d07e0_row5_col8, #T_d07e0_row5_col9, #T_d07e0_row5_col10, #T_d07e0_row5_col11, #T_d07e0_row5_col12, #T_d07e0_row5_col13, #T_d07e0_row5_col14, #T_d07e0_row5_col15, #T_d07e0_row5_col16, #T_d07e0_row5_col17, #T_d07e0_row5_col18, #T_d07e0_row5_col19, #T_d07e0_row5_col20, #T_d07e0_row5_col21, #T_d07e0_row5_col22, #T_d07e0_row5_col23, #T_d07e0_row5_col24, #T_d07e0_row5_col25, #T_d07e0_row5_col26, #T_d07e0_row5_col27, #T_d07e0_row5_col28, #T_d07e0_row5_col29, #T_d07e0_row5_col30, #T_d07e0_row5_col31, #T_d07e0_row6_col0, #T_d07e0 ...
#   text-align: right;
# }
# </style>
# <table id="T_d07e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d07e0_level0_col0" class="col_heading level0 col0" >CMS Certification Number (CCN)</th>
#       <th id="T_d07e0_level0_col1" class="col_heading level0 col1" >ZIP</th>
#       <th id="T_d07e0_level0_col2" class="col_heading level0 col2" >Phone</th>
#       <th id="T_d07e0_level0_col3" class="col_heading level0 col3" >Quality of patient care star rating</th>
#       <th id="T_d07e0_level0_col4" class="col_heading level0 col4" >How often the home health team began their patients care in a timely manner</th>
#       <th id="T_d07e0_level0_col5" class="col_heading level0 col5" >How often the home health team taught patients (or their family caregivers) about their drugs</th>
#       <th id="T_d07e0_level0_col6" class="col_heading level0 col6" >How often the home health team determined whether patients received a flu shot for the current flu season</th>
#       <th id="T_d07e0_level0_col7" class="col_heading level0 col7" >How often patients got better at walking or moving around</th>
#       <th id="T_d07e0_level0_col8" class="col_heading level0 col8" >How often patients got better at getting in and out of bed</th>
#       <th id="T_d07e0_level0_col9" class="col_heading level0 col9" >How often patients got better at bathing</th>
#       <th id="T_d07e0_level0_col10" class="col_heading level0 col10" >How often patients breathing improved</th>
#       <th id="T_d07e0_level0_col11" class="col_heading level0 col11" >How often patients got better at taking their drugs correctly by mouth</th>
#       <th id="T_d07e0_level0_col12" class="col_heading level0 col12" >How often home health patients had to be admitted to the hospital</th>
#       <th id="T_d07e0_level0_col13" class="col_heading level0 col13" >How often patients receiving home health care needed urgent, unplanned care in the ER without being admitted</th>
#       <th id="T_d07e0_level0_col14" class="col_heading level0 col14" >Changes in skin integrity post-acute care: pressure ulcer/injury</th>
#       <th id="T_d07e0_level0_col15" class="col_heading level0 col15" >How often physician-recommended actions to address medication issues were completely timely</th>
#       <th id="T_d07e0_level0_col16" class="col_heading level0 col16" >Percent of Residents Experiencing One or More Falls with Major Injury</th>
#       <th id="T_d07e0_level0_col17" class="col_heading level0 col17" >Application of Percent of Long Term Care Hospital Patients with an Admission and Discharge Functional Assessment and a Care Plan that Addresses Function</th>
#       <th id="T_d07e0_level0_col18" class="col_heading lev

# %% [markdown]
# #### 11609 Medicare certified agencies
# #### 7786 Medicare certified agencies with Quality Star Ratings

# %%
# Percentage of Medicare certified agencies with quality star ratings

percent_agencies_with_star_ratings = 7786/11609
print("Percentage of Medicare certified agencies with star ratings is {:.2f}%.".format(percent_agencies_with_star_ratings))
# Out:
# Percentage of Medicare certified agencies with star ratings is 0.67%.

# %%
df.dtypes
# Out:
# State                                                                                                                                                        object
# CMS Certification Number (CCN)                                                                                                                                int64
# Provider Name                                                                                                                                                object
# Address                                                                                                                                                      object
# City                                                                                                                                                         object
# ZIP                                                                                                                                                           int64
# Phone                                                                                                                                                       float64
# Type of Ownership                                                                                                                                            object
# Offers Nursing Care Services                                                                                                                                 object
# Offers Physical Therapy Services                                                                                                                             object
# Offers Occupational Therapy Services                                                                                                                         object
# Offers Speech Pathology Services                                                                                                                             object
# Offers Medical Social Services                                                                                                                               object
# Offers Home Health Aide Services                                                                                                                             object
# Date Certified                                                                                                                                               object
# Quality of patient care star rating                                                                                                                         float64
# How often the home health team began their patients care in a timely manner                                                                                 float64
# How often the home health team taught patients (or their family caregivers) about their drugs                                                               float64
# How often the home health team determined whether patients received a flu shot for the current flu season                                                   float64
# How often patients got better at walking or moving around                                                                                                   float64
# How often patients got better at getting in and out of bed                                                                                                  float64
# How often patients got better at bathing                                                                                                                    float64
# How often patients breathing improved                                                                                                                       float64
# How often patients got better at taking their drugs correctly by mouth                                                                                      float64
# How often home health patients had to be admitted to the hospital                                                                                           float64
# How often patients receiving home health care needed urgent, unplanned care in the ER without being admitted                                                float64
# Changes in skin integrity post-acute care: pressure ulcer/injury                                                                                            float64
# How often physician-recommended actions to address medication issues were completely timely                                                                 float64
# Percent of Residents Experiencing One or More Falls with Major Injury                                                                                       float64
# Application of Percent of Long Term Care Hospital Patients with an Admission and Discharge Functional Assessment and a Care Plan that Addresses Function    float64
# DTC Numerator                                                                                                                                               float64
# DTC Denominator                                                                                                                                             float64
# DTC Observed Rate                                                                                                                                           float64
# DTC Risk-Standardized Rate                                                                                                                                  float64
# DTC Risk-Standardized Rate (Lower Limit)                                                                                                                    float64
# DTC Risk-Standardized Rate (Upper Limit)                                                                                                                    float64
# DTC Performance Categorization                                                                                                                               object
# PPR Numerator                                                                                                                                               float64
# PPR Denominator                                                                                                                                             float64
# PPR Observed Rate                                                                                                                                           float64
# PPR Risk-Standardized Rate                                                                                                                                  float64
# PPR Risk-Standardized Rate (Lower Limit)                                                                                                                    float64
# PPR Risk-Standardized Rate (Upper Limit)                                                                                                                    float64
# PPR Performance Categorization                                                                                                                               object
# How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally                                 float64
# No. of episodes to calc how much Medicare spends per episode of care at agency, compared to spending at all agencies (national)                             float64
# dtype: object

# %%
# Check if there are any missing values

df.isnull().sum()
# Out:
# State                                                                                                                                                          0
# CMS Certification Number (CCN)                                                                                                                                 0
# Provider Name                                                                                                                                                  0
# Address                                                                                                                                                        0
# City                                                                                                                                                           0
# ZIP                                                                                                                                                            0
# Phone                                                                                                                                                        661
# Type of Ownership                                                                                                                                              0
# Offers Nursing Care Services                                                                                                                                   0
# Offers Physical Therapy Services                                                                                                                               0
# Offers Occupational Therapy Services                                                                                                                           0
# Offers Speech Pathology Services                                                                                                                               0
# Offers Medical Social Services                                                                                                                                 0
# Offers Home Health Aide Services                                                                                                                               0
# Date Certified                                                                                                                                                 0
# Quality of patient care star rating                                                                                                                         3823
# How often the home health team began their patients care in a timely manner                                                                                 3190
# How often the home health team taught patients (or their family caregivers) about their drugs                                                               3210
# How often the home health team determined whether patients received a flu shot for the current flu season                                                   3534
# How often patients got better at walking or moving around                                                                                                   3763
# How often patients got better at getting in and out of bed                                                                                                  3793
# How often patients got better at bathing                                                                                                                    3740
# How often patients breathing improved                                                                                                                       3935
# How often patients got better at taking their drugs correctly by mouth                                                                                      3870
# How often home health patients had to be admitted to the hospital                                                                                           4748
# How often patients receiving home health care needed urgent, unplanned care in the ER without being admitted                                                4748
# Changes in skin integrity post-acute care: pressure ulcer/injury                                                                                            3694
# How often physician-recommended actions to address medication issues were completely timely                                                                 3186
# Percent of Residents Experiencing One or More Falls with Major Injury                                                                                       3202
# Application of Percent of Long Term Care Hospital Patients with an Admission and Discharge Functional Assessment and a Care Plan that Addresses Function    3186
# DTC Numerator                                                                                                                                               4361
# DTC Denominator                                                                                                                                             2360
# DTC Observed Rate                                                                                                                                           4361
# DTC Risk-Standardized Rate                                                                                                                                  4361
# DTC Risk-Standardized Rate (Lower Limit)                                                                                                                    4361
# DTC Risk-Standardized Rate (Upper Limit)                                                                                                                    4361
# DTC Performance Categorization                                                                                                                              2360
# PPR Numerator                                                                                                                                               5319
# PPR Denominator                                                                                                                                             2626
# PPR Observed Rate                                                                                                                                           5319
# PPR Risk-Standardized Rate                                                                                                                                  5319
# PPR Risk-Standardized Rate (Lower Limit)                                                                                                                    5319
# PPR Risk-Standardized Rate (Upper Limit)                                                                                                                    5319
# PPR Performance Categorization                                                                                                                              2626
# How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally                                 3216
# No. of episodes to calc how much Medicare spends per episode of care at agency, compared to spending at all agencies (national)                             2195
# dtype: int64

# %% [markdown]
# ###  Create Star Rating DataFrame to look at the correlation of star rating measures to the overall star rating

# %%
# Create the star_rating_df DataFrame.
star_rating_df = df[['Quality of patient care star rating', 
                     'How often the home health team began their patients care in a timely manner',
                    'How often patients got better at walking or moving around',
                    'How often patients got better at getting in and out of bed',
                    'How often patients got better at bathing',
                    'How often patients breathing improved',
                    'How often patients got better at taking their drugs correctly by mouth',
                    'How often home health patients had to be admitted to the hospital']].copy()
star_rating_df.head().style.set_properties(**{'text-align': 'right'})
# Out:
# <style type="text/css">
# #T_d31cd_row0_col0, #T_d31cd_row0_col1, #T_d31cd_row0_col2, #T_d31cd_row0_col3, #T_d31cd_row0_col4, #T_d31cd_row0_col5, #T_d31cd_row0_col6, #T_d31cd_row0_col7, #T_d31cd_row1_col0, #T_d31cd_row1_col1, #T_d31cd_row1_col2, #T_d31cd_row1_col3, #T_d31cd_row1_col4, #T_d31cd_row1_col5, #T_d31cd_row1_col6, #T_d31cd_row1_col7, #T_d31cd_row2_col0, #T_d31cd_row2_col1, #T_d31cd_row2_col2, #T_d31cd_row2_col3, #T_d31cd_row2_col4, #T_d31cd_row2_col5, #T_d31cd_row2_col6, #T_d31cd_row2_col7, #T_d31cd_row3_col0, #T_d31cd_row3_col1, #T_d31cd_row3_col2, #T_d31cd_row3_col3, #T_d31cd_row3_col4, #T_d31cd_row3_col5, #T_d31cd_row3_col6, #T_d31cd_row3_col7, #T_d31cd_row4_col0, #T_d31cd_row4_col1, #T_d31cd_row4_col2, #T_d31cd_row4_col3, #T_d31cd_row4_col4, #T_d31cd_row4_col5, #T_d31cd_row4_col6, #T_d31cd_row4_col7 {
#   text-align: right;
# }
# </style>
# <table id="T_d31cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d31cd_level0_col0" class="col_heading level0 col0" >Quality of patient care star rating</th>
#       <th id="T_d31cd_level0_col1" class="col_heading level0 col1" >How often the home health team began their patients care in a timely manner</th>
#       <th id="T_d31cd_level0_col2" class="col_heading level0 col2" >How often patients got better at walking or moving around</th>
#       <th id="T_d31cd_level0_col3" class="col_heading level0 col3" >How often patients got better at getting in and out of bed</th>
#       <th id="T_d31cd_level0_col4" class="col_heading level0 col4" >How often patients got better at bathing</th>
#       <th id="T_d31cd_level0_col5" class="col_heading level0 col5" >How often patients breathing improved</th>
#       <th id="T_d31cd_level0_col6" class="col_heading level0 col6" >How often patients got better at taking their drugs correctly by mouth</th>
#       <th id="T_d31cd_level0_col7" class="col_heading level0 col7" >How often home health patients had to be admitted to the hospital</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d31cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d31cd_row0_col0" class="data row0 col0" >4.500000</td>
#       <td id="T_d31cd_row0_col1" class="data row0 col1" >91.200000</td>
#       <td id="T_d31cd_row0_col2" class="data row0 col2" >89.000000</td>
#       <td id="T_d31cd_row0_col3" class="data row0 col3" >90.800000</td>
#       <td id="T_d31cd_row0_col4" class="data row0 col4" >89.900000</td>
#       <td id="T_d31cd_row0_col5" class="data row0 col5" >96.500000</td>
#       <td id="T_d31cd_row0_col6" class="data row0 col6" >95.400000</td>
#       <td id="T_d31cd_row0_col7" class="data row0 col7" >14.900000</td>
#     </tr>
#     <tr>
#       <th id="T_d31cd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d31cd_row1_col0" class="data row1 col0" >2.000000</td>
#       <td id="T_d31cd_row1_col1" class="data row1 col1" >94.400000</td>
#       <td id="T_d31cd_row1_col2" class="data row1 col2" >55.300000</td>
#       <td id="T_d31cd_row1_col3" class="data row1 col3" >67.500000</td>
#       <td id="T_d31cd_row1_col4" class="data row1 col4" >57.900000</td>
#       <td id="T_d31cd_row1_col5" class="data row1 col5" >50.600000</td>
#       <td id="T_d31cd_row1_col6" class="data row1 col6" >62.500000</td>
#       <td id="T_d31cd_row1_col7" class="data row1 col7" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d31cd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d31cd_row2_col0" class="data row2 col0" >2.000000</td>
#       <td id="T_d31cd_row2_col1" class="data row2 col1" >71.900000</td>
#       <td id="T_d31cd_row2_col2" class="data row2 col2" >68.700000</td>
#       <td id="T_d31cd_row2_col3" class="data row2 col3" >70.100000</td>
#       <td id="T_d31cd_row2_col4" class="data row2 col4" >64.400000</td>
#       <td id="T_d31cd_row2_col5" class="data row2 col5" >72.400000</td>
#       <td id="T_d31cd_row2_col6" class="data row2 col6" >58.700000</td>
#       <td id="T_d31cd_row2_col7" class="data row2 col7" >16.400000</td>
#     </tr>
#     <tr>
#       <th id="T_d31cd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d31cd_row3_col0" class="data row3 col0" >4.000000</td>
#       <td id="T_d31cd_row3_col1" class="data row3 col1" >97.900000</td>
#       <td id="T_d31cd_row3_col2" class="data row3 col2" >84.700000</td>
#       <td id="T_d31cd_row3_col3" class="data row3 col3" >87.400000</td>
#       <td id="T_d31cd_row3_col4" class="data row3 col4" >89.200000</td>
#       <td id="T_d31cd_row3_col5" class="data row3 col5" >86.200000</td>
#       <td id="T_d31cd_row3_col6" class="data row3 col6" >88.800000</td>
#       <td id="T_d31cd_row3_col7" class="data row3 col7" >11.900000</td>
#     </tr>
#     <tr>
#       <th id="T_d31cd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d31cd_row4_col0" class="data row4 col0" >2.000000</td>
#       <td id="T_d31cd_row4_col1" class="data row4 col1" >89.900000</td>
#       <td id="T_d31cd_row4_col2" class="data row4 col2" >67.500000</td>
#       <td id="T_d31cd_row4_col3" class="data row4 col3" >79.400000</td>
#       <td id="T_d31cd_row4_col4" class="data row4 col4" >70.800000</td>
#       <td id="T_d31cd_row4_col5" class="data row4 col5" >72.100000</td>
#       <td id="T_d31cd_row4_col6" class="data row4 col6" >59.800000</td>
#       <td id="T_d31cd_row4_col7" class="data row4 col7" >20.900000</td>
#     </tr>
#   </tbody>
# </table>

# %%
star_rating_corr = star_rating_df.corr()
star_rating_corr.style.set_properties(**{'text-align': 'right'})
# Out:
# <style type="text/css">
# #T_b808a_row0_col0, #T_b808a_row0_col1, #T_b808a_row0_col2, #T_b808a_row0_col3, #T_b808a_row0_col4, #T_b808a_row0_col5, #T_b808a_row0_col6, #T_b808a_row0_col7, #T_b808a_row1_col0, #T_b808a_row1_col1, #T_b808a_row1_col2, #T_b808a_row1_col3, #T_b808a_row1_col4, #T_b808a_row1_col5, #T_b808a_row1_col6, #T_b808a_row1_col7, #T_b808a_row2_col0, #T_b808a_row2_col1, #T_b808a_row2_col2, #T_b808a_row2_col3, #T_b808a_row2_col4, #T_b808a_row2_col5, #T_b808a_row2_col6, #T_b808a_row2_col7, #T_b808a_row3_col0, #T_b808a_row3_col1, #T_b808a_row3_col2, #T_b808a_row3_col3, #T_b808a_row3_col4, #T_b808a_row3_col5, #T_b808a_row3_col6, #T_b808a_row3_col7, #T_b808a_row4_col0, #T_b808a_row4_col1, #T_b808a_row4_col2, #T_b808a_row4_col3, #T_b808a_row4_col4, #T_b808a_row4_col5, #T_b808a_row4_col6, #T_b808a_row4_col7, #T_b808a_row5_col0, #T_b808a_row5_col1, #T_b808a_row5_col2, #T_b808a_row5_col3, #T_b808a_row5_col4, #T_b808a_row5_col5, #T_b808a_row5_col6, #T_b808a_row5_col7, #T_b808a_row6_col0, #T_b808a_row6_col1, #T_b808a_row6_col2, #T_b808a_row6_col3, #T_b808a_row6_col4, #T_b808a_row6_col5, #T_b808a_row6_col6, #T_b808a_row6_col7, #T_b808a_row7_col0, #T_b808a_row7_col1, #T_b808a_row7_col2, #T_b808a_row7_col3, #T_b808a_row7_col4, #T_b808a_row7_col5, #T_b808a_row7_col6, #T_b808a_row7_col7 {
#   text-align: right;
# }
# </style>
# <table id="T_b808a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b808a_level0_col0" class="col_heading level0 col0" >Quality of patient care star rating</th>
#       <th id="T_b808a_level0_col1" class="col_heading level0 col1" >How often the home health team began their patients care in a timely manner</th>
#       <th id="T_b808a_level0_col2" class="col_heading level0 col2" >How often patients got better at walking or moving around</th>
#       <th id="T_b808a_level0_col3" class="col_heading level0 col3" >How often patients got better at getting in and out of bed</th>
#       <th id="T_b808a_level0_col4" class="col_heading level0 col4" >How often patients got better at bathing</th>
#       <th id="T_b808a_level0_col5" class="col_heading level0 col5" >How often patients breathing improved</th>
#       <th id="T_b808a_level0_col6" class="col_heading level0 col6" >How often patients got better at taking their drugs correctly by mouth</th>
#       <th id="T_b808a_level0_col7" class="col_heading level0 col7" >How often home health patients had to be admitted to the hospital</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b808a_level0_row0" class="row_heading level0 row0" >Quality of patient care star rating</th>
#       <td id="T_b808a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b808a_row0_col1" class="data row0 col1" >0.433344</td>
#       <td id="T_b808a_row0_col2" class="data row0 col2" >0.821845</td>
#       <td id="T_b808a_row0_col3" class="data row0 col3" >0.756807</td>
#       <td id="T_b808a_row0_col4" class="data row0 col4" >0.821046</td>
#       <td id="T_b808a_row0_col5" class="data row0 col5" >0.751005</td>
#       <td id="T_b808a_row0_col6" class="data row0 col6" >0.810462</td>
#       <td id="T_b808a_row0_col7" class="data row0 col7" >-0.187728</td>
#     </tr>
#     <tr>
#       <th id="T_b808a_level0_row1" class="row_heading level0 row1" >How often the home health team began their patients care in a timely manner</th>
#       <td id="T_b808a_row1_col0" class="data row1 col0" >0.433344</td>
#       <td id="T_b808a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b808a_row1_col2" class="data row1 col2" >0.302806</td>
#       <td id="T_b808a_row1_col3" class="data row1 col3" >0.250379</td>
#       <td id="T_b808a_row1_col4" class="data row1 col4" >0.307788</td>
#       <td id="T_b808a_row1_col5" class="data row1 col5" >0.255505</td>
#       <td id="T_b808a_row1_col6" class="data row1 col6" >0.293271</td>
#       <td id="T_b808a_row1_col7" class="data row1 col7" >-0.002059</td>
#     </tr>
#     <tr>
#       <th id="T_b808a_level0_row2" class="row_heading level0 row2" >How often patients got better at walking or moving around</th>
#       <td id="T_b808a_row2_col0" class="data row2 col0" >0.821845</td>
#       <td id="T_b808a_row2_col1" class="data row2 col1" >0.302806</td>
#       <td id="T_b808a_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b808a_row2_col3" class="data row2 col3" >0.808585</td>
#       <td id="T_b808a_row2_col4" class="data row2 col4" >0.862053</td>
#       <td id="T_b808a_row2_col5" class="data row2 col5" >0.729698</td>
#       <td id="T_b808a_row2_col6" class="data row2 col6" >0.753123</td>
#       <td id="T_b808a_row2_col7" class="data row2 col7" >-0.018372</td>
#     </tr>
#     <tr>
#       <th id="T_b808a_level0_row3" class="row_heading level0 row3" >How often patients got better at getting in and out of bed</th>
#       <td id="T_b808a_row3_col0" class="data row3 col0" >0.756807</td>
#       <td id="T_b808a_row3_col1" class="data row3 col1" >0.250379</td>
#       <td id="T_b808a_row3_col2" class="data row3 col2" >0.808585</td>
#       <td id="T_b808a_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_b808a_row3_col4" class="data row3 col4" >0.784608</td>
#       <td id="T_b808a_row3_col5" class="data row3 col5" >0.707212</td>
#       <td id="T_b808a_row3_col6" class="data row3 col6" >0.701502</td>
#       <td id="T_b808a_row3_col7" class="data row3 col7" >0.016229</td>
#     </tr>
#     <tr>
#       <th id="T_b808a_level0_row4" class="row_heading level0 row4" >How often patients got better at bathing</th>
#       <td id="T_b808a_row4_col0" class="data row4 col0" >0.821046</td>
#       <td id="T_b808a_row4_col1" class="data row4 col1" >0.307788</td>
#       <td id="T_b808a_row4_col2" class="data row4 col2" >0.862053</td>
#       <td id="T_b808a_row4_col3" class="data row4 col3" >0.784608</td>
#       <td id="T_b808a_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_b808a_row4_col5" class="data row4 col5" >0.761498</td>
#       <td id="T_b808a_row4_col6" class="data row4 col6" >0.764294</td>
#       <td id="T_b808a_row4_col7" class="data row4 col7" >-0.031767</td>
#     </tr>
#     <tr>
#       <th id="T_b808a_level0_row5" class="row_heading level0 row5" >How often patients breathing improved</th>
#       <td id="T_b808a_row5_col0" class="data row5 col0" >0.751005</td>
#       <td id="T_b808a_row5_col1" class="data row5 col1" >0.255505</td>
#       <td id="T_b808a_row5_col2" class="data row5 col2" >0.729698</td>
#       <td id="T_b808a_row5_col3" class="data row5 col3" >0.707212</td>
#       <td id="T_b808a_row5_col4" class="data row5 col4" >0.761498</td>
#       <td id="T_b808a_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_b808a_row5_col6" class="data row5 col6" >0.681671</td>
#       <td id="T_b808a_row5_col7" class="data row5 col7" >-0.004590</td>
#     </tr>
#     <tr>
#       <th id="T_b808a_level0_row6" class="row_heading level0 row6" >How often patients got better at taking their drugs correctly by mouth</th>
#       <td id="T_b808a_row6_col0" class="data row6 col0" >0.810462</td>
#       <td id="T_b808a_row6_col1" class="data row6 col1" >0.293271</td>
#       <td id="T_b808a_row6_col2" class="data row6 col2" >0.753123</td>
#       <td id="T_b808a_row6_col3" class="data row6 col3" >0.701502</td>
#       <td id="T_b808a_row6_col4" class="data row6 col4" >0.764294</td>
#       <td id="T_b808a_row6_col5" class="data row6 col5" >0.681671</td>
#       <td id="T_b808a_row6_col6" class="data row6 col6" >1.000000</td>
#       <td id="T_b808a_row6_col7" class="data row6 col7" >-0.005155</td>
#     </tr>
#     <tr>
#       <th id="T_b808a_level0_row7" class="row_heading level0 row7" >How often home health patients had to be admitted to the hospital</th>
#       <td id="T_b808a_row7_col0" class="data row7 col0" >-0.187728</td>
#       <td id="T_b808a_row7_col1" class="data row7 col1" >-0.002059</td>
#       <td id="T_b808a_row7_col2" class="data row7 col2" >-0.018372</td>
#       <td id="T_b808a_row7_col3" class="data row7 col3" >0.016229</td>
#       <td id="T_b808a_row7_col4" class="data row7 col4" >-0.031767</td>
#       <

# %%
fig, ax = plt.subplots(figsize = (20, 10))

# Sample figsize in inches

sns.set(font_scale = 2.0)

g = sns.heatmap(star_rating_corr, xticklabels = star_rating_corr.columns, yticklabels = star_rating_corr.columns, 
            annot = True, linewidths = .2, ax = ax, cmap = 'Spectral', annot_kws={'size': 25})
g.set_xticklabels(g.get_xticklabels(), rotation = 50, fontsize = 25, ha = "right")
g.set_yticklabels(g.get_yticklabels(), rotation = 0, fontsize = 25, va = "center")
plt.title('Correlation of Quality Star Rating Measures', fontsize = 35, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Correlation of Quality Star Rating Measures')

# %%
star_rating_df.describe().style.set_properties(**{'text-align': 'right'})
# Out:
# <style type="text/css">
# #T_66dad_row0_col0, #T_66dad_row0_col1, #T_66dad_row0_col2, #T_66dad_row0_col3, #T_66dad_row0_col4, #T_66dad_row0_col5, #T_66dad_row0_col6, #T_66dad_row0_col7, #T_66dad_row1_col0, #T_66dad_row1_col1, #T_66dad_row1_col2, #T_66dad_row1_col3, #T_66dad_row1_col4, #T_66dad_row1_col5, #T_66dad_row1_col6, #T_66dad_row1_col7, #T_66dad_row2_col0, #T_66dad_row2_col1, #T_66dad_row2_col2, #T_66dad_row2_col3, #T_66dad_row2_col4, #T_66dad_row2_col5, #T_66dad_row2_col6, #T_66dad_row2_col7, #T_66dad_row3_col0, #T_66dad_row3_col1, #T_66dad_row3_col2, #T_66dad_row3_col3, #T_66dad_row3_col4, #T_66dad_row3_col5, #T_66dad_row3_col6, #T_66dad_row3_col7, #T_66dad_row4_col0, #T_66dad_row4_col1, #T_66dad_row4_col2, #T_66dad_row4_col3, #T_66dad_row4_col4, #T_66dad_row4_col5, #T_66dad_row4_col6, #T_66dad_row4_col7, #T_66dad_row5_col0, #T_66dad_row5_col1, #T_66dad_row5_col2, #T_66dad_row5_col3, #T_66dad_row5_col4, #T_66dad_row5_col5, #T_66dad_row5_col6, #T_66dad_row5_col7, #T_66dad_row6_col0, #T_66dad_row6_col1, #T_66dad_row6_col2, #T_66dad_row6_col3, #T_66dad_row6_col4, #T_66dad_row6_col5, #T_66dad_row6_col6, #T_66dad_row6_col7, #T_66dad_row7_col0, #T_66dad_row7_col1, #T_66dad_row7_col2, #T_66dad_row7_col3, #T_66dad_row7_col4, #T_66dad_row7_col5, #T_66dad_row7_col6, #T_66dad_row7_col7 {
#   text-align: right;
# }
# </style>
# <table id="T_66dad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66dad_level0_col0" class="col_heading level0 col0" >Quality of patient care star rating</th>
#       <th id="T_66dad_level0_col1" class="col_heading level0 col1" >How often the home health team began their patients care in a timely manner</th>
#       <th id="T_66dad_level0_col2" class="col_heading level0 col2" >How often patients got better at walking or moving around</th>
#       <th id="T_66dad_level0_col3" class="col_heading level0 col3" >How often patients got better at getting in and out of bed</th>
#       <th id="T_66dad_level0_col4" class="col_heading level0 col4" >How often patients got better at bathing</th>
#       <th id="T_66dad_level0_col5" class="col_heading level0 col5" >How often patients breathing improved</th>
#       <th id="T_66dad_level0_col6" class="col_heading level0 col6" >How often patients got better at taking their drugs correctly by mouth</th>
#       <th id="T_66dad_level0_col7" class="col_heading level0 col7" >How often home health patients had to be admitted to the hospital</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66dad_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_66dad_row0_col0" class="data row0 col0" >7786.000000</td>
#       <td id="T_66dad_row0_col1" class="data row0 col1" >8419.000000</td>
#       <td id="T_66dad_row0_col2" class="data row0 col2" >7846.000000</td>
#       <td id="T_66dad_row0_col3" class="data row0 col3" >7816.000000</td>
#       <td id="T_66dad_row0_col4" class="data row0 col4" >7869.000000</td>
#       <td id="T_66dad_row0_col5" class="data row0 col5" >7674.000000</td>
#       <td id="T_66dad_row0_col6" class="data row0 col6" >7739.000000</td>
#       <td id="T_66dad_row0_col7" class="data row0 col7" >6861.000000</td>
#     </tr>
#     <tr>
#       <th id="T_66dad_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_66dad_row1_col0" class="data row1 col0" >3.249743</td>
#       <td id="T_66dad_row1_col1" class="data row1 col1" >94.127771</td>
#       <td id="T_66dad_row1_col2" class="data row1 col2" >77.846941</td>
#       <td id="T_66dad_row1_col3" class="data row1 col3" >79.067694</td>
#       <td id="T_66dad_row1_col4" class="data row1 col4" >80.683607</td>
#       <td id="T_66dad_row1_col5" class="data row1 col5" >78.400404</td>
#       <td id="T_66dad_row1_col6" class="data row1 col6" >74.704161</td>
#       <td id="T_66dad_row1_col7" class="data row1 col7" >13.995817</td>
#     </tr>
#     <tr>
#       <th id="T_66dad_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_66dad_row2_col0" class="data row2 col0" >1.022742</td>
#       <td id="T_66dad_row2_col1" class="data row2 col1" >8.995277</td>
#       <td id="T_66dad_row2_col2" class="data row2 col2" >14.878897</td>
#       <td id="T_66dad_row2_col3" class="data row2 col3" >14.947192</td>
#       <td id="T_66dad_row2_col4" class="data row2 col4" >14.873205</td>
#       <td id="T_66dad_row2_col5" class="data row2 col5" >17.943180</td>
#       <td id="T_66dad_row2_col6" class="data row2 col6" >16.448971</td>
#       <td id="T_66dad_row2_col7" class="data row2 col7" >3.991187</td>
#     </tr>
#     <tr>
#       <th id="T_66dad_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_66dad_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_66dad_row3_col1" class="data row3 col1" >20.000000</td>
#       <td id="T_66dad_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_66dad_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_66dad_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_66dad_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_66dad_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_66dad_row3_col7" class="data row3 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_66dad_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_66dad_row4_col0" class="data row4 col0" >2.500000</td>
#       <td id="T_66dad_row4_col1" class="data row4 col1" >92.700000</td>
#       <td id="T_66dad_row4_col2" class="data row4 col2" >71.700000</td>
#       <td id="T_66dad_row4_col3" class="data row4 col3" >73.300000</td>
#       <td id="T_66dad_row4_col4" class="data row4 col4" >75.300000</td>
#       <td id="T_66dad_row4_col5" class="data row4 col5" >72.500000</td>
#       <td id="T_66dad_row4_col6" class="data row4 col6" >66.100000</td>
#       <td id="T_66dad_row4_col7" class="data row4 col7" >11.600000</td>
#     </tr>
#     <tr>
#       <th id="T_66dad_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_66dad_row5_col0" class="data row5 col0" >3.500000</td>
#       <td id="T_66dad_row5_col1" class="data row5 col1" >97.800000</td>
#       <td id="T_66dad_row5_col2" class="data row5 col2" >81.100000</td>
#       <td id="T_66dad_row5_col3" class="data row5 col3" >83.200000</td>
#       <td id="T_66dad_row5_col4" class="data row5 col4" >84.300000</td>
#       <td id="T_66dad_row5_col5" class="data row5 col5" >83.700000</td>
#       <td id="T_66dad_row5_col6" class="data row5 col6" >77.900000</td>
#       <td id="T_66dad_row5_col7" class="data row5 col7" >13.900000</td>
#     </tr>
#     <tr>
#       <th id="T_66dad_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_66dad_row6_col0" class="data row6 col0" >4.000000</td>
#       <td id="T_66dad_row6_col1" class="data row6 col1" >99.600000</td>
#       <td id="T_66dad_row6_col2" class="data row6 col2" >87.600000</td>
#       <td id="T_66dad_row6_col3" class="data row6 col3" >88.600000</td>
#       <td id="T_66dad_row6_col4" class="data row6 col4" >90.300000</td>
#       <td id="T_66dad_row6_col5" class="data row6 col5" >90.100000</td>
#       <td id="T_66dad_row6_col6" class="data row6 col6" >86.100000</td>
#       <td id="T_66dad_row6_col7" class="data row6 col7" >16.100000</td>
#     </tr>
#     <tr>
#       <th id="T_66dad_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_66dad_row7_col0" class="data row7 col0" >5.000000</td>
#       <td id="T_66dad_row7_col1" class="data row7 col1" >100.000000</td>
#       <td id="T_66dad_row7_col2" class="data row7 col2" >100.000000</td>
#       <td id="T_66dad_row7_col3" class="data row7 col3" >100.000000</td>
#       <td id="T_66dad_row7_col4" class="data row7 col4" >100.000000</td>
#       <td id="T_66dad_row7_col5" class="data row7 col5" >100.000000</td>
#       <td id="T_66dad_row7_col6" class="data row7 col6" >100.000000</td>
#       <td id="T_66dad_row7_col7" class="data row7 col7" >38.800000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Quality Star Rating Distribution

# %%
star_rating = pd.DataFrame(df['Quality of patient care star rating'].value_counts())
star_rating.style.set_properties(**{'text-align': 'right'})
# Out:
# <style type="text/css">
# #T_652b8_row0_col0, #T_652b8_row1_col0, #T_652b8_row2_col0, #T_652b8_row3_col0, #T_652b8_row4_col0, #T_652b8_row5_col0, #T_652b8_row6_col0, #T_652b8_row7_col0, #T_652b8_row8_col0 {
#   text-align: right;
# }
# </style>
# <table id="T_652b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_652b8_level0_col0" class="col_heading level0 col0" >Quality of patient care star rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_652b8_level0_row0" class="row_heading level0 row0" >3.500000</th>
#       <td id="T_652b8_row0_col0" class="data row0 col0" >1298</td>
#     </tr>
#     <tr>
#       <th id="T_652b8_level0_row1" class="row_heading level0 row1" >3.000000</th>
#       <td id="T_652b8_row1_col0" class="data row1 col0" >1239</td>
#     </tr>
#     <tr>
#       <th id="T_652b8_level0_row2" class="row_heading level0 row2" >4.000000</th>
#       <td id="T_652b8_row2_col0" class="data row2 col0" >1205</td>
#     </tr>
#     <tr>
#       <th id="T_652b8_level0_row3" class="row_heading level0 row3" >2.500000</th>
#       <td id="T_652b8_row3_col0" class="data row3 col0" >1042</td>
#     </tr>
#     <tr>
#       <th id="T_652b8_level0_row4" class="row_heading level0 row4" >4.500000</th>
#       <td id="T_652b8_row4_col0" class="data row4 col0" >1024</td>
#     </tr>
#     <tr>
#       <th id="T_652b8_level0_row5" class="row_heading level0 row5" >2.000000</th>
#       <td id="T_652b8_row5_col0" class="data row5 col0" >802</td>
#     </tr>
#     <tr>
#       <th id="T_652b8_level0_row6" class="row_heading level0 row6" >1.500000</th>
#       <td id="T_652b8_row6_col0" class="data row6 col0" >555</td>
#     </tr>
#     <tr>
#       <th id="T_652b8_level0_row7" class="row_heading level0 row7" >5.000000</th>
#       <td id="T_652b8_row7_col0" class="data row7 col0" >488</td>
#     </tr>
#     <tr>
#       <th id="T_652b8_level0_row8" class="row_heading level0 row8" >1.000000</th>
#       <td id="T_652b8_row8_col0" class="data row8 col0" >133</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize = (6, 6))
ax = sns.countplot(x = 'Quality of patient care star rating', data = df, palette = 'Spectral')
ax.bar_label(ax.containers[0], label_type='edge', fontsize = 10, fontweight = 'bold', padding = 3)
plt.xticks(rotation = 0, size = 10)
plt.yticks(size = 10)
plt.xlabel('Quality Star Rating', size = 12, fontweight = 'bold')
plt.ylabel('# of Agencies', size = 12, fontweight = 'bold')
plt.title('Quality Star Rating Distribution', size = 14, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Quality Star Rating Distribution')

# %%
# Create star_rating_nat_df DataFrame.
star_rating_nat_df = df[['Quality of patient care star rating']].copy()
star_rating_nat_df.head()
# Out:
#    Quality of patient care star rating
# 0                                  4.5
# 1                                  2.0
# 2                                  2.0
# 3                                  4.0
# 4                                  2.0

# %%
star_rating_nat_df.describe()
# Out:
#        Quality of patient care star rating
# count                          7786.000000
# mean                              3.249743
# std                               1.022742
# min                               1.000000
# 25%                               2.500000
# 50%                               3.500000
# 75%                               4.000000
# max                               5.000000

# %%
star_rating_nat_clean_df = star_rating_nat_df.dropna()
star_rating_nat_clean_df.describe()
# Out:
#        Quality of patient care star rating
# count                          7786.000000
# mean                              3.249743
# std                               1.022742
# min                               1.000000
# 25%                               2.500000
# 50%                               3.500000
# 75%                               4.000000
# max                               5.000000

# %%
plt.figure(figsize = (6, 2))
sns.boxplot(data=star_rating_nat_clean_df, x='Quality of patient care star rating', 
            palette = 'Spectral')
plt.xticks(rotation = 0, size = 10)
plt.yticks(size = 10)
plt.xlabel('Quality Star Rating', size = 12, fontweight = 'bold')
plt.ylabel('National', size = 12, fontweight = 'bold')
plt.title('National:  Quality Star Rating', size = 14, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'National:  Quality Star Rating')

# %%
# Create star_rating_state_df DataFrame.
star_rating_state_df = df[['State',
                    'Quality of patient care star rating']].copy()
star_rating_state_df.head()
# Out:
#   State  Quality of patient care star rating
# 0    AK                                  4.5
# 1    AK                                  2.0
# 2    AK                                  2.0
# 3    AK                                  4.0
# 4    AK                                  2.0

# %%
star_rating_state_df.describe()
# Out:
#        Quality of patient care star rating
# count                          7786.000000
# mean                              3.249743
# std                               1.022742
# min                               1.000000
# 25%                               2.500000
# 50%                               3.500000
# 75%                               4.000000
# max                               5.000000

# %%
star_rating_state_clean_df = star_rating_state_df.dropna()
star_rating_state_clean_df.describe()
# Out:
#        Quality of patient care star rating
# count                          7786.000000
# mean                              3.249743
# std                               1.022742
# min                               1.000000
# 25%                               2.500000
# 50%                               3.500000
# 75%                               4.000000
# max                               5.000000

# %%
# Create a State summary by using .groupby
star_rating_state_clean_df.groupby(['State']).agg({'Quality of patient care star rating':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})
# Out:
# <style type="text/css">
# #T_516b5_row0_col0, #T_516b5_row0_col1, #T_516b5_row0_col2, #T_516b5_row0_col3, #T_516b5_row0_col4, #T_516b5_row0_col5, #T_516b5_row1_col0, #T_516b5_row1_col1, #T_516b5_row1_col2, #T_516b5_row1_col3, #T_516b5_row1_col4, #T_516b5_row1_col5, #T_516b5_row2_col0, #T_516b5_row2_col1, #T_516b5_row2_col2, #T_516b5_row2_col3, #T_516b5_row2_col4, #T_516b5_row2_col5, #T_516b5_row3_col0, #T_516b5_row3_col1, #T_516b5_row3_col2, #T_516b5_row3_col3, #T_516b5_row3_col4, #T_516b5_row3_col5, #T_516b5_row4_col0, #T_516b5_row4_col1, #T_516b5_row4_col2, #T_516b5_row4_col3, #T_516b5_row4_col4, #T_516b5_row4_col5, #T_516b5_row5_col0, #T_516b5_row5_col1, #T_516b5_row5_col2, #T_516b5_row5_col3, #T_516b5_row5_col4, #T_516b5_row5_col5, #T_516b5_row6_col0, #T_516b5_row6_col1, #T_516b5_row6_col2, #T_516b5_row6_col3, #T_516b5_row6_col4, #T_516b5_row6_col5, #T_516b5_row7_col0, #T_516b5_row7_col1, #T_516b5_row7_col2, #T_516b5_row7_col3, #T_516b5_row7_col4, #T_516b5_row7_col5, #T_516b5_row8_col0, #T_516b5_row8_col1, #T_516b5_row8_col2, #T_516b5_row8_col3, #T_516b5_row8_col4, #T_516b5_row8_col5, #T_516b5_row9_col0, #T_516b5_row9_col1, #T_516b5_row9_col2, #T_516b5_row9_col3, #T_516b5_row9_col4, #T_516b5_row9_col5, #T_516b5_row10_col0, #T_516b5_row10_col1, #T_516b5_row10_col2, #T_516b5_row10_col3, #T_516b5_row10_col4, #T_516b5_row10_col5, #T_516b5_row11_col0, #T_516b5_row11_col1, #T_516b5_row11_col2, #T_516b5_row11_col3, #T_516b5_row11_col4, #T_516b5_row11_col5, #T_516b5_row12_col0, #T_516b5_row12_col1, #T_516b5_row12_col2, #T_516b5_row12_col3, #T_516b5_row12_col4, #T_516b5_row12_col5, #T_516b5_row13_col0, #T_516b5_row13_col1, #T_516b5_row13_col2, #T_516b5_row13_col3, #T_516b5_row13_col4, #T_516b5_row13_col5, #T_516b5_row14_col0, #T_516b5_row14_col1, #T_516b5_row14_col2, #T_516b5_row14_col3, #T_516b5_row14_col4, #T_516b5_row14_col5, #T_516b5_row15_col0, #T_516b5_row15_col1, #T_516b5_row15_col2, #T_516b5_row15_col3, #T_516b5_row15_col4, #T_516b5_row15_col5, #T_516b5_row16_col0, #T_516b5_row16_col1, #T_516b5_row16_col2, #T_516b5_row16_col3, #T_516b5_row16_col4, #T_516b5_row16_col5, #T_516b5_row17_col0, #T_516b5_row17_col1, #T_516b5_row17_col2, #T_516b5_row17_col3, #T_516b5_row17_col4, #T_516b5_row17_col5, #T_516b5_row18_col0, #T_516b5_row18_col1, #T_516b5_row18_col2, #T_516b5_row18_col3, #T_516b5_row18_col4, #T_516b5_row18_col5, #T_516b5_row19_col0, #T_516b5_row19_col1, #T_516b5_row19_col2, #T_516b5_row19_col3, #T_516b5_row19_col4, #T_516b5_row19_col5, #T_516b5_row20_col0, #T_516b5_row20_col1, #T_516b5_row20_col2, #T_516b5_row20_col3, #T_516b5_row20_col4, #T_516b5_row20_col5, #T_516b5_row21_col0, #T_516b5_row21_col1, #T_516b5_row21_col2, #T_516b5_row21_col3, #T_516b5_row21_col4, #T_516b5_row21_col5, #T_516b5_row22_col0, #T_516b5_row22_col1, #T_516b5_row22_col2, #T_516b5_row22_col3, #T_516b5_row22_col4, #T_516b5_row22_col5, #T_516b5_row23_col0, #T_516b5_row23_col1, #T_516b5_row23_col2, #T_516b5_row23_col3, #T_516b5_row23_col4, #T_516b5_row23_col5, #T_516b5_row24_col0, #T_516b5_row24_col1, #T_516b5_row24_col2, #T_516b5_row24_col3, #T_516b5_row24_col4, #T_516b5_row24_col5, #T_516b5_row25_col0, #T_516b5_row25_col1, #T_516b5_row25_col2, #T_516b5_row25_col3, #T_516b5_row25_col4, #T_516b5_row25_col5, #T_516b5_row26_col0, #T_516b5_row26_col1, #T_516b5_row26_col2, #T_516b5_row26_col3, #T_516b5_row26_col4, #T_516b5_row26_col5, #T_516b5_row27_col0, #T_516b5_row27_col1, #T_516b5_row27_col2, #T_516b5_row27_col3, #T_516b5_row27_col4, #T_516b5_row27_col5, #T_516b5_row28_col0, #T_516b5_row28_col1, #T_516b5_row28_col2, #T_516b5_row28_col3, #T_516b5_row28_col4, #T_516b5_row28_col5, #T_516b5_row29_col0, #T_516b5_row29_col1, #T_516b5_row29_col2, #T_516b5_row29_col3, #T_516b5_row29_col4, #T_516b5_row29_col5, #T_516b5_row30_col0, #T_516b5_row30_col1, #T_516b5_row30_col2, #T_516b5_row30_col3, #T_516b5_row30_col4, #T_516b5_row30_col5, #T_516b5_row31_col0, #T_516b5_row31_col1, #T_516b5_row31_col2, #T_516b5_row31_col3, #T_516b5_row31_col4, #T_516b5_row31_col5, #T_516b5_row32_col0, #T_516b ...
#   text-align: right;
# }
# </style>
# <table id="T_516b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_516b5_level0_col0" class="col_heading level0 col0" >State</th>
#       <th id="T_516b5_level0_col1" class="col_heading level0 col1" colspan="5">Quality of patient care star rating</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_516b5_level1_col0" class="col_heading level1 col0" ></th>
#       <th id="T_516b5_level1_col1" class="col_heading level1 col1" >count</th>
#       <th id="T_516b5_level1_col2" class="col_heading level1 col2" >mean</th>
#       <th id="T_516b5_level1_col3" class="col_heading level1 col3" >median</th>
#       <th id="T_516b5_level1_col4" class="col_heading level1 col4" >min</th>
#       <th id="T_516b5_level1_col5" class="col_heading level1 col5" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_516b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_516b5_row0_col0" class="data row0 col0" >AK</td>
#       <td id="T_516b5_row0_col1" class="data row0 col1" >14</td>
#       <td id="T_5

# %%
star_rating_state_clean_df.groupby(['State']).agg({'Quality of patient care star rating':['count', 'mean', 'median', 'min', 'max']}).reset_index().tail(27).style.set_properties(**{'text-align': 'right'})
# Out:
# <style type="text/css">
# #T_d7f6b_row0_col0, #T_d7f6b_row0_col1, #T_d7f6b_row0_col2, #T_d7f6b_row0_col3, #T_d7f6b_row0_col4, #T_d7f6b_row0_col5, #T_d7f6b_row1_col0, #T_d7f6b_row1_col1, #T_d7f6b_row1_col2, #T_d7f6b_row1_col3, #T_d7f6b_row1_col4, #T_d7f6b_row1_col5, #T_d7f6b_row2_col0, #T_d7f6b_row2_col1, #T_d7f6b_row2_col2, #T_d7f6b_row2_col3, #T_d7f6b_row2_col4, #T_d7f6b_row2_col5, #T_d7f6b_row3_col0, #T_d7f6b_row3_col1, #T_d7f6b_row3_col2, #T_d7f6b_row3_col3, #T_d7f6b_row3_col4, #T_d7f6b_row3_col5, #T_d7f6b_row4_col0, #T_d7f6b_row4_col1, #T_d7f6b_row4_col2, #T_d7f6b_row4_col3, #T_d7f6b_row4_col4, #T_d7f6b_row4_col5, #T_d7f6b_row5_col0, #T_d7f6b_row5_col1, #T_d7f6b_row5_col2, #T_d7f6b_row5_col3, #T_d7f6b_row5_col4, #T_d7f6b_row5_col5, #T_d7f6b_row6_col0, #T_d7f6b_row6_col1, #T_d7f6b_row6_col2, #T_d7f6b_row6_col3, #T_d7f6b_row6_col4, #T_d7f6b_row6_col5, #T_d7f6b_row7_col0, #T_d7f6b_row7_col1, #T_d7f6b_row7_col2, #T_d7f6b_row7_col3, #T_d7f6b_row7_col4, #T_d7f6b_row7_col5, #T_d7f6b_row8_col0, #T_d7f6b_row8_col1, #T_d7f6b_row8_col2, #T_d7f6b_row8_col3, #T_d7f6b_row8_col4, #T_d7f6b_row8_col5, #T_d7f6b_row9_col0, #T_d7f6b_row9_col1, #T_d7f6b_row9_col2, #T_d7f6b_row9_col3, #T_d7f6b_row9_col4, #T_d7f6b_row9_col5, #T_d7f6b_row10_col0, #T_d7f6b_row10_col1, #T_d7f6b_row10_col2, #T_d7f6b_row10_col3, #T_d7f6b_row10_col4, #T_d7f6b_row10_col5, #T_d7f6b_row11_col0, #T_d7f6b_row11_col1, #T_d7f6b_row11_col2, #T_d7f6b_row11_col3, #T_d7f6b_row11_col4, #T_d7f6b_row11_col5, #T_d7f6b_row12_col0, #T_d7f6b_row12_col1, #T_d7f6b_row12_col2, #T_d7f6b_row12_col3, #T_d7f6b_row12_col4, #T_d7f6b_row12_col5, #T_d7f6b_row13_col0, #T_d7f6b_row13_col1, #T_d7f6b_row13_col2, #T_d7f6b_row13_col3, #T_d7f6b_row13_col4, #T_d7f6b_row13_col5, #T_d7f6b_row14_col0, #T_d7f6b_row14_col1, #T_d7f6b_row14_col2, #T_d7f6b_row14_col3, #T_d7f6b_row14_col4, #T_d7f6b_row14_col5, #T_d7f6b_row15_col0, #T_d7f6b_row15_col1, #T_d7f6b_row15_col2, #T_d7f6b_row15_col3, #T_d7f6b_row15_col4, #T_d7f6b_row15_col5, #T_d7f6b_row16_col0, #T_d7f6b_row16_col1, #T_d7f6b_row16_col2, #T_d7f6b_row16_col3, #T_d7f6b_row16_col4, #T_d7f6b_row16_col5, #T_d7f6b_row17_col0, #T_d7f6b_row17_col1, #T_d7f6b_row17_col2, #T_d7f6b_row17_col3, #T_d7f6b_row17_col4, #T_d7f6b_row17_col5, #T_d7f6b_row18_col0, #T_d7f6b_row18_col1, #T_d7f6b_row18_col2, #T_d7f6b_row18_col3, #T_d7f6b_row18_col4, #T_d7f6b_row18_col5, #T_d7f6b_row19_col0, #T_d7f6b_row19_col1, #T_d7f6b_row19_col2, #T_d7f6b_row19_col3, #T_d7f6b_row19_col4, #T_d7f6b_row19_col5, #T_d7f6b_row20_col0, #T_d7f6b_row20_col1, #T_d7f6b_row20_col2, #T_d7f6b_row20_col3, #T_d7f6b_row20_col4, #T_d7f6b_row20_col5, #T_d7f6b_row21_col0, #T_d7f6b_row21_col1, #T_d7f6b_row21_col2, #T_d7f6b_row21_col3, #T_d7f6b_row21_col4, #T_d7f6b_row21_col5, #T_d7f6b_row22_col0, #T_d7f6b_row22_col1, #T_d7f6b_row22_col2, #T_d7f6b_row22_col3, #T_d7f6b_row22_col4, #T_d7f6b_row22_col5, #T_d7f6b_row23_col0, #T_d7f6b_row23_col1, #T_d7f6b_row23_col2, #T_d7f6b_row23_col3, #T_d7f6b_row23_col4, #T_d7f6b_row23_col5, #T_d7f6b_row24_col0, #T_d7f6b_row24_col1, #T_d7f6b_row24_col2, #T_d7f6b_row24_col3, #T_d7f6b_row24_col4, #T_d7f6b_row24_col5, #T_d7f6b_row25_col0, #T_d7f6b_row25_col1, #T_d7f6b_row25_col2, #T_d7f6b_row25_col3, #T_d7f6b_row25_col4, #T_d7f6b_row25_col5, #T_d7f6b_row26_col0, #T_d7f6b_row26_col1, #T_d7f6b_row26_col2, #T_d7f6b_row26_col3, #T_d7f6b_row26_col4, #T_d7f6b_row26_col5 {
#   text-align: right;
# }
# </style>
# <table id="T_d7f6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7f6b_level0_col0" class="col_heading level0 col0" >State</th>
#       <th id="T_d7f6b_level0_col1" class="col_heading level0 col1" colspan="5">Quality of patient care star rating</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_d7f6b_level1_col0" class="col_heading level1 col0" ></th>
#       <th id="T_d7f6b_level1_col1" class="col_heading level1 col1" >count</th>
#       <th id="T_d7f6b_level1_col2" class="col_heading level1 col2" >mean</th>
#       <th id="T_d7f6b_level1_col3" class="col_heading level1 col3" >median</th>
#       <th id="T_d7f6b_level1_col4" class="col_heading level1 col4" >min</th>
#       <th id="T_d7f6b_level1_col5" class="col_heading level1 col5" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7f6b_level0_row0" class="row_heading level0 row0" >28</th>
#       <td id="T_d7f6b_row0_col0" class="data row0 col0" >MT</td>
#       <td id="T_d7f6b_row0_col1" class="data row0 col1" >22</td>
#       <td id="T_d7f6b_row0_col2" class="data row0 col2" >2.909091</td>
#       <td id="T_d7f6b_row0_col3" class="data row0 col3" >3.000000</td>
#       <td id="T_d7f6b_row0_col4" class="data row0 col4" >1.500000</td>
#       <td id="T_d7f6b_row0_col5" class="data row0 col5" >4.500000</td>
#     </tr>
#     <tr>
#       <th id="T_d7f6b_level0_row1" class="row_heading level0 row1" >29</th>
#       <td id="T_d7f6b_row1_col0" class="data row1 col0" >NC</td>
#       <td id="T_d7f6b_row1_col1" class="data row1 col1" >157</td>
#       <td id="T_d7f6b_row1_col2" class="data row1 col2" >3.449045</td>
#       <td id="T_d7f6b_row1_col3" class="data row1 col3" >3.500000</td>
#       <td id="T_d7f6b_row1_col4" class="data row1 col4" >1.500000</td>
#       <td id="T_d7f6b_row1_col5" class="data row1 col5" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7f6b_level0_row2" class="row_heading level0 row2" >30</th>
#       <td id="T_d7f6b_row2_col0" class="data row2 col0" >ND</td>
#       <td id="T_d7f6b_row2_col1" class="data row2 col1" >14</td>
#       <td id="T_d7f6b_row2_col2" class="data row2 col2" >3.178571</td>
#       <td id="T_d7f6b_row2_col3" class="data row2 col3" >3.000000</td>
#       <td id="T_d7f6b_row2_col4" class="data row2 col4" >2.000000</td>
#       <td id="T_d7f6b_row2_col5" class="data row2 col5" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7f6b_level0_row3" class="row_heading level0 row3" >31</th>
#       <td id="T_d7f6b_row3_col0" class="data row3 col0" >NE</td>
#       <td id="T_d7f6b_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_d7f6b_row3_col2" class="data row3 col2" >3.153846</td>
#       <td id="T_d7f6b_row3_col3" class="data row3 col3" >3.000000</td>
#       <td id="T_d7f6b_row3_col4" class="data row3 col4" >1.500000</td>
#       <td id="T_d7f6b_row3_col5" class="data row3 col5" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7f6b_level0_row4" class="row_heading level0 row4" >32</th>
#       <td id="T_d7f6b_row4_col0" class="data row4 col0" >NH</td>
#       <td id="T_d7f6b_row4_col1" class="data row4 col1" >23</td>
#       <td id="T_d7f6b_row4_col2" class="data row4 col2" >2.978261</td>
#       <td id="T_d7f6b_row4_col3" class="data row4 col3" >3.000000</td>
#       <td id="T_d7f6b_row4_col4" class="data row4 col4" >1.500000</td>
#       <td id="T_d7f6b_row4_col5" class="data row4 col5" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7f6b_level0_row5" class="row_heading level0 row5" >33</th>
#       <td id="T_d7f6b_row5_col0" class="data row5 col0" >NJ</td>
#       <td id="T_d7f6b_row5_col1" class="data row5 col1" >40</td>
#       <td id="T_d7f6b_row5_col2" class="data row5 col2" >3.612500</td>
#       <td id="T_d7f6b_row5_col3" class="data row5 col3" >3.500000</td>
#       <td id="T_d7f6b_row5_col4" class="data row5 col4" >2.500000</td>
#       <td id="T_d7f6b_row5_col5" class="data row5 col5" >4.500000</td>
#     </tr>
#     <tr>
#       <th id="T_d7f6b_level0_row6" class="row_heading level0 row6" >34</th>
#       <td id="T_d7f6b_row6_col0" class="data row6 col0" >NM</td>
#       <td id="T_d7f6b_row6_col1" class="data row6 col1" >64</td>
#       <td id="T_d7f6b_row6_col2" class="data row6 col2" >3.132812</td>
#       <td id="T_d7f6b_row6_col3" class="data row6 col3" >3.000000</td>
#       <td id="T_d7f6b_row6_col4" class="data row6 col4" >1.500000</td>
#       <td id="T_d7f6b_row6_col5" class="data row6 col5" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7f6b_level0_row7" class="row_heading level0 row7" >35</th>
#       <td id="T_d7f6b_row7_col0" class="data row7 col0" >NV</td>
#       <td id="T_d7f6b_row7_col1" class="data

# %%
plt.figure(figsize = (25, 30))
sns.boxplot(data=star_rating_state_clean_df, x='Quality of patient care star rating', 
            y='State', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Quality of Patient Care Star Rating', size = 23, fontweight = 'bold')
plt.ylabel('State/Territory', size = 23, fontweight = 'bold')
plt.title('Quality of Patient Care Star Rating \n by State/Territory', size = 25, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Quality of Patient Care Star Rating \n by State/Territory')

# %%
star_rating_state_avg = star_rating_state_clean_df.groupby(['State']).agg({'Quality of patient care star rating':['mean']}).reset_index()
star_rating_state_avg
# Out:
#    State Quality of patient care star rating
#                                         mean
# 0     AK                            2.642857
# 1     AL                            3.964912
# 2     AR                            3.596774
# 3     AZ                            3.360465
# 4     CA                            3.214708
# 5     CO                            3.213675
# 6     CT                            2.971014
# 7     DC                            3.444444
# 8     DE                            3.576923
# 9     FL                            3.623457
# 10    GA                            3.600000
# 11    GU                            2.333333
# 12    HI                            3.115385
# 13    IA                            2.940000
# 14    ID                            3.553191
# 15    IL                            3.003378
# 16    IN                            3.267361
# 17    KS                            3.181319
# 18    KY                            3.747126
# 19    LA                            3.700000
# 20    MA                            2.913534
# 21    MD                            3.800000
# 22    ME                            3.275000
# 23    MI                            3.215134
# 24    MN                            2.740196
# 25    MO                            3.211382
# 26    MP                            2.500000
# 27    MS                            3.895349
# 28    MT                            2.909091
# 29    NC                            3.449045
# 30    ND                            3.178571
# 31    NE                            3.153846
# 32    NH                            2.978261
# 33    NJ                            3.612500
# 34    NM                            3.132812
# 35    NV                            2.813953
# 36    NY                            3.303922
# 37    OH                            3.188889
# 38    OK                            3.091837
# 39    OR                            3.072917
# 40    PA                            3.273973
# 41    PR                            3.638889
# 42    RI                            3.447368
# 43    SC                            3.771429
# 44    SD                            3.309524
# 45    TN                            3.809735
# 46    TX                            2.877395
# 47    UT                            3.493590
# 48    VA                            3.299479
# 49    VI                            3.750000
# 50    VT                            2.800000
# 51    WA                            3.796875
# 52    WI                            2.993671
# 53    WV                            3.823529
# 54    WY                            3.000000

# %%
# States having the TOP 15 average quality star rating
star_new_sort = star_rating_state_clean_df.groupby(['State'])['Quality of patient care star rating'].mean().sort_values(ascending=False).reset_index()
star_new_sort_top = star_new_sort.head(15)
star_new_sort_top
# Out:
#    State  Quality of patient care star rating
# 0     AL                             3.964912
# 1     MS                             3.895349
# 2     WV                             3.823529
# 3     TN                             3.809735
# 4     MD                             3.800000
# 5     WA                             3.796875
# 6     SC                             3.771429
# 7     VI                             3.750000
# 8     KY                             3.747126
# 9     LA                             3.700000
# 10    PR                             3.638889
# 11    FL                             3.623457
# 12    NJ                             3.612500
# 13    GA                             3.600000
# 14    AR                             3.596774

# %%
plt.figure(figsize = (8, 8))
ax = sns.barplot(data=star_new_sort_top, x='Quality of patient care star rating', 
            y='State', palette = 'Spectral')
ax.bar_label(ax.containers[0], label_type='edge', fontsize = 10, fontweight = 'bold', padding = 3, fmt = '%#.2f')
plt.xticks(rotation = 0, size = 10)
plt.yticks(size = 10)
plt.xlabel('Average Quality of Patient Care Star Rating', size = 12, fontweight = 'bold')
plt.ylabel('State/Territory', size = 12, fontweight = 'bold')
plt.title('Top 15 Quality of Patient Care Star Rating \n by State/Territory', size = 12, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Top 15 Quality of Patient Care Star Rating \n by State/Territory')

# %%
#States having the BOTTOM 15 average quality star rating
star_new_sort_bottom = star_new_sort.tail(15)
star_new_sort_bottom
# Out:
#    State  Quality of patient care star rating
# 40    IL                             3.003378
# 41    WY                             3.000000
# 42    WI                             2.993671
# 43    NH                             2.978261
# 44    CT                             2.971014
# 45    IA                             2.940000
# 46    MA                             2.913534
# 47    MT                             2.909091
# 48    TX                             2.877395
# 49    NV                             2.813953
# 50    VT                             2.800000
# 51    MN                             2.740196
# 52    AK                             2.642857
# 53    MP                             2.500000
# 54    GU                             2.333333

# %%
plt.figure(figsize = (8, 8))
ax = sns.barplot(data=star_new_sort_bottom, x='Quality of patient care star rating', 
            y='State', palette = 'Spectral')
ax.bar_label(ax.containers[0], label_type='edge', fontsize = 10, fontweight = 'bold', padding = 3, fmt = '%#.2f')
plt.xticks(rotation = 0, size = 10)
plt.yticks(size = 10)
plt.xlabel('Average Quality of Patient Care Star Rating', size = 12, fontweight = 'bold')
plt.ylabel('State/Territory', size = 12, fontweight = 'bold')
plt.title('Bottom 15 Quality of Patient Care Star Rating \n by State/Territory', size = 12, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Bottom 15 Quality of Patient Care Star Rating \n by State/Territory')

# %%
usa = gpd.read_file('Resources/states.shp')
usa.head()
# Out:
#      STATE_NAME  DRAWSEQ STATE_FIPS          SUB_REGION STATE_ABBR  \
# 0        Hawaii        1         15             Pacific         HI
# 1    Washington        2         53             Pacific         WA
# 2       Montana        3         30            Mountain         MT
# 3         Maine        4         23         New England         ME
# 4  North Dakota        5         38  West North Central         ND
#
#                                             geometry
# 0  MULTIPOLYGON (((-160.07380 22.00418, -160.0497...
# 1  MULTIPOLYGON (((-122.40202 48.22522, -122.4628...
# 2  POLYGON ((-111.47543 44.70216, -111.48080 44.6...
# 3  MULTIPOLYGON (((-69.77728 44.07415, -69.85993 ...
# 4  POLYGON ((-98.73044 45.93827, -99.00683 45.939...

# %%
usa.tail()
# Out:
#    STATE_NAME  DRAWSEQ STATE_FIPS          SUB_REGION STATE_ABBR  \
# 46   Arkansas       47         05  West South Central         AR
# 47  Louisiana       48         22  West South Central         LA
# 48    Florida       49         12      South Atlantic         FL
# 49   Michigan       50         26  East North Central         MI
# 50     Alaska       51         02             Pacific         AK
#
#                                              geometry
# 46  POLYGON ((-94.46169 34.19677, -94.45262 34.508...
# 47  MULTIPOLYGON (((-93.70752 30.23958, -93.69938 ...
# 48  MULTIPOLYGON (((-80.78566 28.78519, -80.76242 ...
# 49  MULTIPOLYGON (((-88.49753 48.17380, -88.62533 ...
# 50  MULTIPOLYGON (((-161.33379 58.73325, -161.3824...

# %%
usa.plot()
# Out:
# <AxesSubplot: >

# %%
usa.loc[0, 'geometry']

# %%
usa[usa.STATE_ABBR == 'WI'].plot()
# Out:
# <AxesSubplot: >

# %%
usa[usa.SUB_REGION == 'East North Central'].plot()
# Out:
# <AxesSubplot: >

# %%
def state_plotter(states, us_map = True):

#Setting up us_map as an input.  If you want to return states that are spread out, leave it set to true.
#If you are plotting bordering states and prefer to zoom in.

    #Instantiate a matplotlib figure
    #To change size, use x_lim and y_lim.  Changing the figsize will not change the size of the map.
    fig, ax = plt.subplots(figsize = (30, 30))
    
    if us_map:   #These codes will execute if us_map is set to True (default)
        
        #The following series of if/elif/else statements provide control over
        #whether Alaska and Hawaii will show up in the map.  Because of their
        #distance from the lower 48, and the size of Alaska, we don't want them
        #in the map unless necessary.
        
        if 'HI' in states:
            usa[0:50].plot(ax=ax, alpha = 0.3)
            
        elif 'AK' in states:
            usa[1:51].plot(ax=ax, alpha = 0.3)
            
        elif 'AK' and 'HI' in states:
            usa[0:51].plot(ax=ax, alpha = 0.3)
            
        else:
            usa[1:50].plot(ax=ax, alpha = 0.3)
            
        #The following loop will go through the list of input state abbreviations and plot them
        #ax=ax makes the states appear on the initial matplotlib figure.
        
        for n in states:
            usa[usa.STATE_ABBR == f'{n}'].plot(ax=ax, edgecolor = 'y', linewidth = 2)
            
        #If you choose not to have the first layer of the whole USA, this will plot states on their own.
        
    elif us_map == False:
        for n in states:
            usa[usa.STATE_ABBR == f'{n}'].plot(ax=ax, edgecolor = 'y', linewidth = 2)

# %%
state_plotter(['NV', 'IN', 'WI', 'CA'])

# %%
state_plotter(['IL', 'IN', 'WI', 'MI', 'OH'], us_map = False)

# %% [markdown]
# ### Quality Star Rating Based on Type of Ownership
# * GOVERNMENT - COMBINATION GOVT & VOLUNTARY
# * GOVERNMENT - LOCAL
# * GOVERNMENT - STATE/COUNTY
# * PROPRIETARY
# * VOLUNTARY NON-PROFIT - OTHER
# * VOLUNTARY NON-PROFIT - PRIVATE
# * VOLUNTARY NON PROFIT - RELIGIOUS AFFILIATION

# %%
# Create the star_rating_too_df DataFrame.
star_rating_too_df = df[['Type of Ownership',
                    'Quality of patient care star rating', 
                     'How often the home health team began their patients care in a timely manner',
                    'How often patients got better at walking or moving around',
                    'How often patients got better at getting in and out of bed',
                    'How often patients got better at bathing',
                    'How often patients breathing improved',
                    'How often patients got better at taking their drugs correctly by mouth',
                    'How often home health patients had to be admitted to the hospital']].copy()
star_rating_too_df.head().style.set_properties(**{'text-align': 'right'})

# %%
star_rating_too_df.tail().style.set_properties(**{'text-align': 'right'})

# %%
star_rating_too_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
star_rating_too_clean_df = star_rating_too_df.dropna()
star_rating_too_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
# Create star_rating__only_too_clean_df DataFrame.
star_rating_only_too_clean_df = star_rating_too_clean_df[['Type of Ownership',
                    'Quality of patient care star rating']].copy()
star_rating_only_too_clean_df.head().style.set_properties(**{'text-align': 'right'})

# %%
# Total of ownership type for each type
total_ownership_type_by_type = star_rating_too_clean_df.groupby(['Type of Ownership']).count()['Quality of patient care star rating']
total_ownership_type_by_type

# %%
# Create a Type of Ownership summary using .groupby
star_rating_too_clean_df.groupby(['Type of Ownership']).agg({'Quality of patient care star rating':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (18, 12))
sns.boxplot(data=star_rating_only_too_clean_df, x='Quality of patient care star rating', 
            y='Type of Ownership', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Quality of Patient Care Star Rating', size = 25, fontweight = 'bold')
plt.ylabel('Type of Ownership', size = 25, fontweight = 'bold')
plt.title('Quality of Patient Care Star Rating \n by Type of Ownership', size = 27, fontweight = 'bold')

# %%
# Create a Type of Ownership DataFrame for each type

gov_combo_df = star_rating_too_clean_df[star_rating_too_clean_df["Type of Ownership"] == 'GOVERNMENT - COMBINATION GOVT & VOLUNTARY']

gov_loc_df = star_rating_too_clean_df[star_rating_too_clean_df["Type of Ownership"] == 'GOVERNMENT - LOCAL']

gov_state_county_df = star_rating_too_clean_df[star_rating_too_clean_df["Type of Ownership"] == 'GOVERNMENT - STATE/COUNTY']

prop_df = star_rating_too_clean_df[star_rating_too_clean_df["Type of Ownership"] == 'PROPRIETARY']

vol_non_prof_rel_df = star_rating_too_clean_df[star_rating_too_clean_df["Type of Ownership"] == 'VOLUNTARY NON PROFIT - RELIGIOUS AFFILIATION']

vol_non_prof_other_df = star_rating_too_clean_df[star_rating_too_clean_df["Type of Ownership"] == 'VOLUNTARY NON-PROFIT - OTHER']

vol_non_prof_priv_df = star_rating_too_clean_df[star_rating_too_clean_df["Type of Ownership"] == 'VOLUNTARY NON-PROFIT - PRIVATE']

# %%
gov_combo_df.head().style.set_properties(**{'text-align': 'right'})

# %%
gov_combo_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
gov_combo_star_rating = pd.DataFrame(gov_combo_df['Quality of patient care star rating'].value_counts())
gov_combo_star_rating.style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (6, 6))
ax = sns.countplot(x = 'Quality of patient care star rating', data = gov_combo_df, palette = 'Spectral')
ax.bar_label(ax.containers[0], label_type='edge', fontsize = 10, fontweight = 'bold', padding = 3)
plt.xticks(rotation = 0, size = 10)
plt.yticks(size = 10)
plt.xlabel('Quality Star Rating', size = 12, fontweight = 'bold')
plt.ylabel('# of Agencies', size = 12, fontweight = 'bold')
plt.title('Government Combination \n Quality Star Rating Distribution', size = 14, fontweight = 'bold')

# %%
gov_loc_df.head().style.set_properties(**{'text-align': 'right'})

# %%
gov_loc_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
gov_loc_star_rating = pd.DataFrame(gov_loc_df['Quality of patient care star rating'].value_counts())
gov_loc_star_rating.style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (6, 6))
ax = sns.countplot(x = 'Quality of patient care star rating', data = gov_loc_df, palette = 'Spectral')
ax.bar_label(ax.containers[0], label_type='edge', fontsize = 10, fontweight = 'bold', padding = 3)
plt.xticks(rotation = 0, size = 10)
plt.yticks(size = 10)
plt.xlabel('Quality Star Rating', size = 12, fontweight = 'bold')
plt.ylabel('# of Agencies', size = 12, fontweight = 'bold')
plt.title('Government Local \n Quality Star Rating Distribution', size = 14, fontweight = 'bold')

# %%
gov_state_county_df.head().style.set_properties(**{'text-align': 'right'})

# %%
gov_state_county_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
gov_state_county_star_rating = pd.DataFrame(gov_state_county_df['Quality of patient care star rating'].value_counts())
gov_state_county_star_rating.style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (6, 6))
ax = sns.countplot(x = 'Quality of patient care star rating', data = gov_state_county_df, palette = 'Spectral')
ax.bar_label(ax.containers[0], label_type='edge', fontsize = 10, fontweight = 'bold', padding = 3)
plt.xticks(rotation = 0, size = 10)
plt.yticks(size = 10)
plt.xlabel('Quality Star Rating', size = 12, fontweight = 'bold')
plt.ylabel('# of Agencies', size = 12, fontweight = 'bold')
plt.title('Government State/County \n Quality Star Rating Distribution', size = 14, fontweight = 'bold')

# %%
prop_df.head().style.set_properties(**{'text-align': 'right'})

# %%
prop_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
prop_star_rating = pd.DataFrame(prop_df['Quality of patient care star rating'].value_counts())
prop_star_rating.style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (6, 6))
ax = sns.countplot(x = 'Quality of patient care star rating', data = prop_df, palette = 'Spectral')
ax.bar_label(ax.containers[0], label_type='edge', fontsize = 10, fontweight = 'bold', padding = 3)
plt.xticks(rotation = 0, size = 10)
plt.yticks(size = 10)
plt.xlabel('Quality Star Rating', size = 12, fontweight = 'bold')
plt.ylabel('# of Agencies', size = 12, fontweight = 'bold')
plt.title('Proprietary \n Quality Star Rating Distribution', size = 14, fontweight = 'bold')

# %%
vol_non_prof_rel_df.head().style.set_properties(**{'text-align': 'right'})

# %%
vol_non_prof_rel_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
vol_non_prof_rel_star_rating = pd.DataFrame(vol_non_prof_rel_df['Quality of patient care star rating'].value_counts())
vol_non_prof_rel_star_rating.style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (6, 6))
ax = sns.countplot(x = 'Quality of patient care star rating', data = vol_non_prof_rel_df, palette = 'Spectral')
ax.bar_label(ax.containers[0], label_type='edge', fontsize = 10, fontweight = 'bold', padding = 3)
plt.xticks(rotation = 0, size = 10)
plt.yticks(size = 10)
plt.xlabel('Quality Star Rating', size = 12, fontweight = 'bold')
plt.ylabel('# of Agencies', size = 12, fontweight = 'bold')
plt.title('Voluntary Non-Profit Religious \n Quality Star Rating Distribution', size = 14, fontweight = 'bold')

# %%
vol_non_prof_other_df.head().style.set_properties(**{'text-align': 'right'})

# %%
vol_non_prof_other_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
vol_non_prof_other_star_rating = pd.DataFrame(vol_non_prof_other_df['Quality of patient care star rating'].value_counts())
vol_non_prof_other_star_rating.style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (6, 6))
ax = sns.countplot(x = 'Quality of patient care star rating', data = vol_non_prof_other_df, palette = 'Spectral')
ax.bar_label(ax.containers[0], label_type='edge', fontsize = 10, fontweight = 'bold', padding = 3)
plt.xticks(rotation = 0, size = 10)
plt.yticks(size = 10)
plt.xlabel('Quality Star Rating', size = 12, fontweight = 'bold')
plt.ylabel('# of Agencies', size = 12, fontweight = 'bold')
plt.title('Voluntary Non-Profit Other \n Quality Star Rating Distribution', size = 14, fontweight = 'bold')

# %%
vol_non_prof_priv_df.head().style.set_properties(**{'text-align': 'right'})

# %%
vol_non_prof_priv_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
vol_non_prof_priv_star_rating = pd.DataFrame(vol_non_prof_priv_df['Quality of patient care star rating'].value_counts())
vol_non_prof_priv_star_rating.style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (6, 6))
ax = sns.countplot(x = 'Quality of patient care star rating', data = vol_non_prof_priv_df, palette = 'Spectral')
ax.bar_label(ax.containers[0], label_type='edge', fontsize = 10, fontweight = 'bold', padding = 3)
plt.xticks(rotation = 0, size = 10)
plt.yticks(size = 10)
plt.xlabel('Quality Star Rating', size = 12, fontweight = 'bold')
plt.ylabel('# of Agencies', size = 12, fontweight = 'bold')
plt.title('Voluntary Non-Profit Private \n Quality Star Rating Distribution', size = 14, fontweight = 'bold')

# %% [markdown]
# ## Publically Reported Measures *NOT* Included in the Star Rating Measure (10)
#
# ### These measures include the following:
# * How often the home health team taught patients (or their family caregivers) about their drugs
# * How often the home health team determined whether patients received a flu shot for the current flu season
# * How often patients receiving home health care needed urgent, unplanned care in the ER without being admitted
# * Changes in skin integrity post-acute care: pressure ulcer/injury
# * How often physician-recommended actions to address medication issues were completely timely
# * Percent of Residents Experiencing One or More Falls with Major Injury
# * Application of Percent of Long Term Care Hospital Patients with an Admission and Discharge Functional Assessment and a Care Plan that Addresses Function
# * Discharge to Community (DTC) Risk-Standardized Rate
# * Potentially Preventable 30-Day Post Discharge Readmission (PPR) Risk-Standardized Rate
# * How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally

# %% [markdown]
# ### Home Health Team Teaching Patients About Their Drugs

# %%
# Create the teach_drugs_nat_df DataFrame.
teach_drugs_nat_df = df[['How often the home health team taught patients (or their family caregivers) about their drugs']].copy()
teach_drugs_nat_df.head().style.set_properties(**{'text-align': 'right'})

# %%
teach_drugs_nat_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
teach_drugs_nat_clean_df = teach_drugs_nat_df.dropna()
teach_drugs_nat_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (15, 2))
sns.boxplot(data=teach_drugs_nat_clean_df, x='How often the home health team taught patients (or their family caregivers) about their drugs', 
            palette = 'Spectral')
plt.xticks(rotation = 0, size = 12)
plt.yticks(size = 12)
plt.xlabel('Patients Taught About Their Drugs (%)', size = 12, fontweight = 'bold')
plt.ylabel('National', size = 12, fontweight = 'bold')
plt.title('National:  Patients Taught About Their Drugs', size = 14, fontweight = 'bold')

# %%
# Create the teach_drugs_state_df DataFrame.
teach_drugs_state_df = df[['State',
                    'How often the home health team taught patients (or their family caregivers) about their drugs']].copy()
teach_drugs_state_df.head().style.set_properties(**{'text-align': 'right'})

# %%
teach_drugs_state_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
teach_drugs_state_clean_df = teach_drugs_state_df.dropna()
teach_drugs_state_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
# Create a teach_drugs_state_clean_df summary using .groupby
teach_drugs_state_clean_df.groupby(['State']).agg({'How often the home health team taught patients (or their family caregivers) about their drugs':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
# Create a teach_drugs_state_clean_df summary using .groupby
teach_drugs_state_clean_df.groupby(['State']).agg({'How often the home health team taught patients (or their family caregivers) about their drugs':['count', 'mean', 'median', 'min', 'max']}).reset_index().head(28).style.set_properties(**{'text-align': 'right'})

# %%
# Create a teach_drugs_state_clean_df summary using .groupby
teach_drugs_state_clean_df.groupby(['State']).agg({'How often the home health team taught patients (or their family caregivers) about their drugs':['count', 'mean', 'median', 'min', 'max']}).reset_index().tail(27).style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (25, 30))
sns.boxplot(data=teach_drugs_state_clean_df, x='How often the home health team taught patients (or their family caregivers) about their drugs', 
            y='State', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Patients Taught About Their Drugs (%)', size = 23, fontweight = 'bold')
plt.ylabel('State/Territory', size = 23, fontweight = 'bold')
plt.title('Patients Taught About Their Drugs \n by State/Territory', size = 25, fontweight = 'bold')

# %%
# Create the teach_drugs_too_df DataFrame.
teach_drugs_too_df = df[['Type of Ownership',
                    'How often the home health team taught patients (or their family caregivers) about their drugs']].copy()
teach_drugs_too_df.head().style.set_properties(**{'text-align': 'right'})

# %%
teach_drugs_too_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
teach_drugs_too_clean_df = teach_drugs_too_df.dropna()
teach_drugs_too_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
teach_drugs_too_clean_df.shape

# %%
teach_drugs_too_clean_df = teach_drugs_too_clean_df.loc[(teach_drugs_too_clean_df['Type of Ownership'] != '-')]

# %%
teach_drugs_too_clean_df.shape

# %%
# Create a teach_drugs_too_clean_df summary using .groupby
teach_drugs_too_clean_df.groupby(['Type of Ownership']).agg({'How often the home health team taught patients (or their family caregivers) about their drugs':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (18, 12))
sns.boxplot(data=teach_drugs_too_clean_df, x='How often the home health team taught patients (or their family caregivers) about their drugs', 
            y='Type of Ownership', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Patients Taught About Their Drugs (%)', size = 25, fontweight = 'bold')
plt.ylabel('Type of Ownership', size = 25, fontweight = 'bold')
plt.title('Patients Taught About Their Drugs \n by Type of Ownership', size = 27, fontweight = 'bold')

# %% [markdown]
# ### How Often the Home Health Team Determined Whether Patients Received a Flu Shot for the Current Flu Season

# %%
# Create the flu_shot_nat_df DataFrame.
flu_shot_nat_df = df[['How often the home health team determined whether patients received a flu shot for the current flu season']].copy()
flu_shot_nat_df.head().style.set_properties(**{'text-align': 'right'})

# %%
flu_shot_nat_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
flu_shot_nat_clean_df = flu_shot_nat_df.dropna()
flu_shot_nat_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (15, 2))
sns.boxplot(data=flu_shot_nat_clean_df, x='How often the home health team determined whether patients received a flu shot for the current flu season', 
            palette = 'Spectral')
plt.xticks(rotation = 0, size = 12)
plt.yticks(size = 12)
plt.xlabel('Flu Shot for the Current Flu Season (%)', size = 12, fontweight = 'bold')
plt.ylabel('National', size = 12, fontweight = 'bold')
plt.title('National:  Flu Shot for the Current Flu Season', size = 14, fontweight = 'bold')

# %%
# Create the flu_shot_state_df DataFrame.
flu_shot_state_df = df[['State',
                    'How often the home health team determined whether patients received a flu shot for the current flu season']].copy()
flu_shot_state_df.head().style.set_properties(**{'text-align': 'right'})

# %%
flu_shot_state_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
flu_shot_state_clean_df = flu_shot_state_df.dropna()
flu_shot_state_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
# Create a flu_shot_state_clean_df summary using .groupby
flu_shot_state_clean_df.groupby(['State']).agg({'How often the home health team determined whether patients received a flu shot for the current flu season':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
# Create a flu_shot_state_clean_df summary using .groupby
flu_shot_state_clean_df.groupby(['State']).agg({'How often the home health team determined whether patients received a flu shot for the current flu season':['count', 'mean', 'median', 'min', 'max']}).reset_index().tail(27).style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (20, 30))
sns.boxplot(data=flu_shot_state_clean_df, x='How often the home health team determined whether patients received a flu shot for the current flu season', 
            y='State', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Flu Shot for the Current Flu Season (%)', size = 25, fontweight = 'bold')
plt.ylabel('State/Territory', size = 25, fontweight = 'bold')
plt.title('Flu Shot for the Current Flu Season \n by State/Territory', size = 27, fontweight = 'bold')

# %%
# Create the flu_shot_too_df DataFrame.
flu_shot_too_df = df[['Type of Ownership',
                    'How often the home health team determined whether patients received a flu shot for the current flu season']].copy()
flu_shot_too_df.head().style.set_properties(**{'text-align': 'right'})

# %%
flu_shot_too_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
flu_shot_too_clean_df = flu_shot_too_df.dropna()
flu_shot_too_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
flu_shot_too_clean_df.shape

# %%
flu_shot_too_clean_df.isna().sum()

# %%
flu_shot_too_clean_df = flu_shot_too_clean_df.loc[(flu_shot_too_clean_df['Type of Ownership'] != '-')]

# %%
flu_shot_too_clean_df.shape

# %%
# Create a flu_shot_too_clean_df summary using .groupby
flu_shot_too_clean_df.groupby(['Type of Ownership']).agg({'How often the home health team determined whether patients received a flu shot for the current flu season':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (18, 12))
sns.boxplot(data=flu_shot_too_clean_df, x='How often the home health team determined whether patients received a flu shot for the current flu season', 
            y='Type of Ownership', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Flu Shot for the Current Flu Season (%)', size = 25, fontweight = 'bold')
plt.ylabel('Type of Ownership', size = 25, fontweight = 'bold')
plt.title('Flu Shot for the Current Flu Season \n by Type of Ownership', size = 27, fontweight = 'bold')

# %% [markdown]
# ### Patients Needed Urgent, Unplanned Care in the ER without Being Admitted

# %%
# Create the urgent_er_nat_df DataFrame.
urgent_er_nat_df = df[['How often patients receiving home health care needed urgent, unplanned care in the ER without being admitted']].copy()
urgent_er_nat_df.head().style.set_properties(**{'text-align': 'right'})

# %%
urgent_er_nat_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
urgent_er_nat_clean_df = urgent_er_nat_df.dropna()
urgent_er_nat_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (25, 6))
sns.boxplot(data=urgent_er_nat_clean_df, x='How often patients receiving home health care needed urgent, unplanned care in the ER without being admitted', 
            palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Urgent, Unplanned Care in the ER without being Admitted (%)', size = 25, fontweight = 'bold')
plt.ylabel('National', size = 25, fontweight = 'bold')
plt.title('National:  Urgent, Unplanned Care in the ER without being Admitted', size = 27, fontweight = 'bold')

# %%
# Create the urgent_er_state_df DataFrame.
urgent_er_state_df = df[['State',
                    'How often patients receiving home health care needed urgent, unplanned care in the ER without being admitted']].copy()
urgent_er_state_df.head().style.set_properties(**{'text-align': 'right'})

# %%
urgent_er_state_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
urgent_er_state_clean_df = urgent_er_state_df.dropna()
urgent_er_state_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
# Create a urgent_er_state_clean_df summary using .groupby
urgent_er_state_clean_df.groupby(['State']).agg({'How often patients receiving home health care needed urgent, unplanned care in the ER without being admitted':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
# Create a urgent_er_state_clean_df summary using .groupby
urgent_er_state_clean_df.groupby(['State']).agg({'How often patients receiving home health care needed urgent, unplanned care in the ER without being admitted':['count', 'mean', 'median', 'min', 'max']}).reset_index().tail(27).style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (20, 30))
sns.boxplot(data=urgent_er_state_clean_df, x='How often patients receiving home health care needed urgent, unplanned care in the ER without being admitted', 
            y='State', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Urgent, Unplanned Care in the ER without being Admitted (%)', size = 25, fontweight = 'bold')
plt.ylabel('State/Territory', size = 25, fontweight = 'bold')
plt.title('Urgent, Unplanned Care in the ER without being Admitted \n by State/Territory', size = 27, fontweight = 'bold')

# %%
# Create the urgent_er_too_df DataFrame.
urgent_er_too_df = df[['Type of Ownership',
                    'How often patients receiving home health care needed urgent, unplanned care in the ER without being admitted']].copy()
urgent_er_too_df.head().style.set_properties(**{'text-align': 'right'})

# %%
urgent_er_too_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
urgent_er_too_clean_df = urgent_er_too_df.dropna()
urgent_er_too_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
urgent_er_too_clean_df.shape

# %%
urgent_er_too_clean_df = urgent_er_too_clean_df.loc[(urgent_er_too_clean_df['Type of Ownership'] != '-')]
urgent_er_too_clean_df.shape

# %%
# Create a urgent_er_too_clean_df summary using .groupby
urgent_er_too_clean_df.groupby(['Type of Ownership']).agg({'How often patients receiving home health care needed urgent, unplanned care in the ER without being admitted':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (18, 12))
sns.boxplot(data=urgent_er_too_clean_df, x='How often patients receiving home health care needed urgent, unplanned care in the ER without being admitted', 
            y='Type of Ownership', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Urgent, Unplanned Care in the ER without being Admitted (%)', size = 25, fontweight = 'bold')
plt.ylabel('Type of Ownership', size = 25, fontweight = 'bold')
plt.title('Urgent, Unplanned Care in the ER without being Admitted \n by Type of Ownership', size = 27, fontweight = 'bold')

# %% [markdown]
# ### Changes in Skin Integrity Post-Acute Care: Pressure Ulcer/Injury

# %%
# Create the pres_ulcer_nat_df DataFrame.
pres_ulcer_nat_df = df[['Changes in skin integrity post-acute care: pressure ulcer/injury']].copy()
pres_ulcer_nat_df.head().style.set_properties(**{'text-align': 'right'})

# %%
pres_ulcer_nat_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
pres_ulcer_nat_clean_df = pres_ulcer_nat_df.dropna()
pres_ulcer_nat_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (25, 6))
sns.boxplot(data=pres_ulcer_nat_clean_df, x='Changes in skin integrity post-acute care: pressure ulcer/injury', 
            palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Changes in Skin Integrity Post-Acute Care: Pressure Ulcer/Injury (%)', size = 25, fontweight = 'bold')
plt.ylabel('National', size = 25, fontweight = 'bold')
plt.title('National:  Changes in Skin Integrity Post-Acute Care: Pressure Ulcer/Injury', size = 27, fontweight = 'bold')

# %%
# Create the pres_ulcer_state_df DataFrame.
pres_ulcer_state_df = df[['State',
                    'Changes in skin integrity post-acute care: pressure ulcer/injury']].copy()
pres_ulcer_state_df.head().style.set_properties(**{'text-align': 'right'})

# %%
pres_ulcer_state_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
pres_ulcer_state_clean_df = pres_ulcer_state_df.dropna()
pres_ulcer_state_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
# Create a pres_ulcer_state_clean_df summary using .groupby
pres_ulcer_state_clean_df.groupby(['State']).agg({'Changes in skin integrity post-acute care: pressure ulcer/injury':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
# Create a pres_ulcer_state_clean_df summary using .groupby
pres_ulcer_state_clean_df.groupby(['State']).agg({'Changes in skin integrity post-acute care: pressure ulcer/injury':['count', 'mean', 'median', 'min', 'max']}).reset_index().tail(27).style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (20, 30))
sns.boxplot(data=pres_ulcer_state_clean_df, x='Changes in skin integrity post-acute care: pressure ulcer/injury', 
            y='State', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Changes in Skin Integrity Post-Acute Care: Pressure Ulcer/Injury (%)', size = 25, fontweight = 'bold')
plt.ylabel('State/Territory', size = 25, fontweight = 'bold')
plt.title('Changes in Skin Integrity Post-Acute Care: Pressure Ulcer/Injury \n by State/Territory', size = 27, fontweight = 'bold')

# %%
# Create the pres_ulcer_too_df DataFrame.
pres_ulcer_too_df = df[['Type of Ownership',
                    'Changes in skin integrity post-acute care: pressure ulcer/injury']].copy()
pres_ulcer_too_df.head().style.set_properties(**{'text-align': 'right'})

# %%
pres_ulcer_too_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
pres_ulcer_too_clean_df = pres_ulcer_too_df.dropna()
pres_ulcer_too_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
pres_ulcer_too_clean_df.shape

# %%
pres_ulcer_too_clean_df = pres_ulcer_too_clean_df.loc[(pres_ulcer_too_clean_df['Type of Ownership'] != '-')]
pres_ulcer_too_clean_df.shape

# %%
# Create a pres_ulcer_too_clean_df summary using .groupby
pres_ulcer_too_clean_df.groupby(['Type of Ownership']).agg({'Changes in skin integrity post-acute care: pressure ulcer/injury':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (18, 12))
sns.boxplot(data=pres_ulcer_too_clean_df, x='Changes in skin integrity post-acute care: pressure ulcer/injury', 
            y='Type of Ownership', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Changes in Skin Integrity Post-Acute Care: Pressure Ulcer/Injury (%)', size = 25, fontweight = 'bold')
plt.ylabel('Type of Ownership', size = 25, fontweight = 'bold')
plt.title('Changes in Skin Integrity Post-Acute Care: Pressure Ulcer/Injury \n by Type of Ownership', size = 27, fontweight = 'bold')

# %% [markdown]
# ### Physician-Recommended Actions to Address Medication Issues were Completely Timely

# %%
# Create the med_time_nat_df DataFrame.
med_time_nat_df = df[['How often physician-recommended actions to address medication issues were completely timely']].copy()
med_time_nat_df.head().style.set_properties(**{'text-align': 'right'})

# %%
med_time_nat_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
med_time_nat_clean_df = med_time_nat_df.dropna()
med_time_nat_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (25, 6))
sns.boxplot(data=med_time_nat_clean_df, x='How often physician-recommended actions to address medication issues were completely timely', 
            palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Medication Issues were Completed Timely (%)', size = 25, fontweight = 'bold')
plt.ylabel('National', size = 25, fontweight = 'bold')
plt.title('National:  Medication Issues were Completed Timely', size = 27, fontweight = 'bold')

# %%
# Create the med_time_state_df DataFrame.
med_time_state_df = df[['State',
                    'How often physician-recommended actions to address medication issues were completely timely']].copy()
med_time_state_df.head().style.set_properties(**{'text-align': 'right'})

# %%
med_time_state_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
med_time_state_clean_df = med_time_state_df.dropna()
med_time_state_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
# Create a med_time_state_clean_df summary using .groupby
med_time_state_clean_df.groupby(['State']).agg({'How often physician-recommended actions to address medication issues were completely timely':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
# Create a med_time_state_clean_df summary using .groupby
med_time_state_clean_df.groupby(['State']).agg({'How often physician-recommended actions to address medication issues were completely timely':['count', 'mean', 'median', 'min', 'max']}).reset_index().tail(27).style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (20, 30))
sns.boxplot(data=med_time_state_clean_df, x='How often physician-recommended actions to address medication issues were completely timely', 
            y='State', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Medication Issues were Completed Timely (%)', size = 25, fontweight = 'bold')
plt.ylabel('State/Territory', size = 25, fontweight = 'bold')
plt.title('Medication Issues were Completed Timely \n by State/Territory', size = 27, fontweight = 'bold')

# %%
# Create the med_time_too_df DataFrame.
med_time_too_df = df[['Type of Ownership',
                    'How often physician-recommended actions to address medication issues were completely timely']].copy()
med_time_too_df.head().style.set_properties(**{'text-align': 'right'})

# %%
med_time_too_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
med_time_too_clean_df = med_time_too_df.dropna()
med_time_too_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
med_time_too_clean_df.shape

# %%
med_time_too_clean_df = med_time_too_clean_df.loc[(med_time_too_clean_df['Type of Ownership'] != '-')]
med_time_too_clean_df.shape

# %%
# Create a med_time_too_clean_df summary using .groupby
med_time_too_clean_df.groupby(['Type of Ownership']).agg({'How often physician-recommended actions to address medication issues were completely timely':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (18, 12))
sns.boxplot(data=med_time_too_clean_df, x='How often physician-recommended actions to address medication issues were completely timely', 
            y='Type of Ownership', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Medication Issues were Completed Timely (%)', size = 25, fontweight = 'bold')
plt.ylabel('Type of Ownership', size = 25, fontweight = 'bold')
plt.title('Medication Issues were Completed Timely \n by Type of Ownership', size = 27, fontweight = 'bold')

# %% [markdown]
# ### Percent of Residents Experiencing One or More Falls with Major Injury

# %%
# Create the falls_maj_inj_nat_df DataFrame.
falls_maj_inj_nat_df = df[['Percent of Residents Experiencing One or More Falls with Major Injury']].copy()
falls_maj_inj_nat_df.head().style.set_properties(**{'text-align': 'right'})

# %%
falls_maj_inj_nat_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
falls_maj_inj_nat_clean_df = falls_maj_inj_nat_df.dropna()
falls_maj_inj_nat_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (25, 6))
sns.boxplot(data=falls_maj_inj_nat_clean_df, x='Percent of Residents Experiencing One or More Falls with Major Injury', 
            palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Residents Experiencing One or More Falls with Major Injury (%)', size = 25, fontweight = 'bold')
plt.ylabel('National', size = 25, fontweight = 'bold')
plt.title('National:  Percent of Residents Experiencing One or More Falls with Major Injury', size = 27, fontweight = 'bold')

# %%
# Create the falls_maj_inj_state_df DataFrame.
falls_maj_inj_state_df = df[['State',
                    'Percent of Residents Experiencing One or More Falls with Major Injury']].copy()
falls_maj_inj_state_df.head().style.set_properties(**{'text-align': 'right'})

# %%
falls_maj_inj_state_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
falls_maj_inj_state_clean_df = falls_maj_inj_state_df.dropna()
falls_maj_inj_state_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
# Create a falls_maj_inj_state_clean_df summary using .groupby
falls_maj_inj_state_clean_df.groupby(['State']).agg({'Percent of Residents Experiencing One or More Falls with Major Injury':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
# Create a falls_maj_inj_state_clean_df summary using .groupby
falls_maj_inj_state_clean_df.groupby(['State']).agg({'Percent of Residents Experiencing One or More Falls with Major Injury':['count', 'mean', 'median', 'min', 'max']}).reset_index().tail(27).style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (20, 30))
sns.boxplot(data=falls_maj_inj_state_clean_df, x='Percent of Residents Experiencing One or More Falls with Major Injury', 
            y='State', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Residents Experiencing One or More Falls with Major Injury (%)', size = 25, fontweight = 'bold')
plt.ylabel('State/Territory', size = 25, fontweight = 'bold')
plt.title('Percent of Residents Experiencing One or More Falls with Major Injury \n by State/Territory', size = 27, fontweight = 'bold')

# %%
# Create the falls_maj_inj_too_df DataFrame.
falls_maj_inj_too_df = df[['Type of Ownership',
                    'Percent of Residents Experiencing One or More Falls with Major Injury']].copy()
falls_maj_inj_too_df.head().style.set_properties(**{'text-align': 'right'})

# %%
falls_maj_inj_too_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
falls_maj_inj_too_clean_df = falls_maj_inj_too_df.dropna()
falls_maj_inj_too_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
falls_maj_inj_too_clean_df.shape

# %%
falls_maj_inj_too_clean_df = falls_maj_inj_too_clean_df.loc[(falls_maj_inj_too_clean_df['Type of Ownership'] != '-')]
falls_maj_inj_too_clean_df.shape

# %%
# Create a falls_maj_inj_too_clean_df summary using .groupby
falls_maj_inj_too_clean_df.groupby(['Type of Ownership']).agg({'Percent of Residents Experiencing One or More Falls with Major Injury':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (18, 12))
sns.boxplot(data=falls_maj_inj_too_clean_df, x='Percent of Residents Experiencing One or More Falls with Major Injury', 
            y='Type of Ownership', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Residents Experiencing One or More Falls with Major Injury (%)', size = 25, fontweight = 'bold')
plt.ylabel('Type of Ownership', size = 25, fontweight = 'bold')
plt.title('Percent of Residents Experiencing One or More Falls with Major Injury \n by Type of Ownership', size = 27, fontweight = 'bold')

# %% [markdown]
# ### Application of Percent of Long Term Care Hospital Patients with an Admission and Discharge Functional Assessment and a Care Plan that Addresses Function

# %%
# Create the cp_func_nat_df DataFrame.
cp_func_nat_df = df[['Application of Percent of Long Term Care Hospital Patients with an Admission and Discharge Functional Assessment and a Care Plan that Addresses Function']].copy()
cp_func_nat_df.head().style.set_properties(**{'text-align': 'right'})

# %%
cp_func_nat_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
cp_func_nat_clean_df = cp_func_nat_df.dropna()
cp_func_nat_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (25, 6))
sns.boxplot(data=cp_func_nat_clean_df, x='Application of Percent of Long Term Care Hospital Patients with an Admission and Discharge Functional Assessment and a Care Plan that Addresses Function', 
            palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Functional Assessment and a Care Plan that Addresses Function (%)', size = 25, fontweight = 'bold')
plt.ylabel('National', size = 25, fontweight = 'bold')
plt.title('National:  Functional Assessment and a Care Plan that Addresses Function', size = 27, fontweight = 'bold')

# %%
# Create the cp_func_state_df DataFrame.
cp_func_state_df = df[['State',
                    'Application of Percent of Long Term Care Hospital Patients with an Admission and Discharge Functional Assessment and a Care Plan that Addresses Function']].copy()
cp_func_state_df.head().style.set_properties(**{'text-align': 'right'})

# %%
cp_func_state_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
cp_func_state_clean_df = cp_func_state_df.dropna()
cp_func_state_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
# Create a cp_func_state_clean_df summary using .groupby
cp_func_state_clean_df.groupby(['State']).agg({'Application of Percent of Long Term Care Hospital Patients with an Admission and Discharge Functional Assessment and a Care Plan that Addresses Function':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (20, 30))
sns.boxplot(data=cp_func_state_clean_df, x='Application of Percent of Long Term Care Hospital Patients with an Admission and Discharge Functional Assessment and a Care Plan that Addresses Function', 
            y='State', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Functional Assessment and a Care Plan that Addresses Function (%)', size = 25, fontweight = 'bold')
plt.ylabel('State/Territory', size = 25, fontweight = 'bold')
plt.title('Functional Assessment and a Care Plan that Addresses Function \n by State/Territory', size = 27, fontweight = 'bold')

# %%
# Create the cp_func_too_df DataFrame.
cp_func_too_df = df[['Type of Ownership',
                    'Application of Percent of Long Term Care Hospital Patients with an Admission and Discharge Functional Assessment and a Care Plan that Addresses Function']].copy()
cp_func_too_df.head().style.set_properties(**{'text-align': 'right'})

# %%
cp_func_too_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
cp_func_too_clean_df = cp_func_too_df.dropna()
cp_func_too_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
cp_func_too_clean_df.shape

# %%
cp_func_too_clean_df = cp_func_too_clean_df.loc[(cp_func_too_clean_df['Type of Ownership'] != '-')]
cp_func_too_clean_df.shape

# %%
# Create a cp_func_too_clean_df summary using .groupby
cp_func_too_clean_df.groupby(['Type of Ownership']).agg({'Application of Percent of Long Term Care Hospital Patients with an Admission and Discharge Functional Assessment and a Care Plan that Addresses Function':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (18, 12))
sns.boxplot(data=cp_func_too_clean_df, x='Application of Percent of Long Term Care Hospital Patients with an Admission and Discharge Functional Assessment and a Care Plan that Addresses Function', 
            y='Type of Ownership', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Functional Assessment and a Care Plan that Addresses Function (%)', size = 25, fontweight = 'bold')
plt.ylabel('Type of Ownership', size = 25, fontweight = 'bold')
plt.title('Functional Assessment and a Care Plan that Addresses Function \n by Type of Ownership', size = 27, fontweight = 'bold')

# %% [markdown]
# ### Discharge to Community (DTC) Risk-Standardized Rate

# %%
# Create the dtc_nat_df DataFrame.
dtc_nat_df = df[['DTC Risk-Standardized Rate']].copy()
dtc_nat_df.head().style.set_properties(**{'text-align': 'right'})

# %%
dtc_nat_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
dtc_nat_clean_df = dtc_nat_df.dropna()
dtc_nat_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (25, 6))
sns.boxplot(data=dtc_nat_clean_df, x='DTC Risk-Standardized Rate', 
            palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('DTC Risk-Standardized Rate (%)', size = 25, fontweight = 'bold')
plt.ylabel('National', size = 25, fontweight = 'bold')
plt.title('National:  Discharge to Community (DTC) Standardized Rate', size = 27, fontweight = 'bold')

# %%
# Create the dtc_state_df DataFrame.
dtc_state_df = df[['State',
                    'DTC Risk-Standardized Rate']].copy()
dtc_state_df.head().style.set_properties(**{'text-align': 'right'})

# %%
dtc_state_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
dtc_state_clean_df = dtc_state_df.dropna()
dtc_state_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
# Create a dtc_state_clean_df summary using .groupby
dtc_state_clean_df.groupby(['State']).agg({'DTC Risk-Standardized Rate':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
# Create a dtc_state_clean_df summary using .groupby
dtc_state_clean_df.groupby(['State']).agg({'DTC Risk-Standardized Rate':['count', 'mean', 'median', 'min', 'max']}).reset_index().tail(27).style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (20, 30))
sns.boxplot(data=dtc_state_clean_df, x='DTC Risk-Standardized Rate', 
            y='State', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('DTC Risk-Standardized Rate (%)', size = 25, fontweight = 'bold')
plt.ylabel('State/Territory', size = 25, fontweight = 'bold')
plt.title('Discharge to Community (DTC) Risk-Standardized Rate \n by State/Territory', size = 27, fontweight = 'bold')

# %%
# Create the dtc_too_df DataFrame.
dtc_too_df = df[['Type of Ownership',
                    'DTC Risk-Standardized Rate']].copy()
dtc_too_df.head().style.set_properties(**{'text-align': 'right'})

# %%
dtc_too_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
dtc_too_clean_df = dtc_too_df.dropna()
dtc_too_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
dtc_too_clean_df.shape

# %%
dtc_too_clean_df = dtc_too_clean_df.loc[(dtc_too_clean_df['Type of Ownership'] != '-')]
dtc_too_clean_df.shape

# %%
# Create a dtc_too_clean_df summary using .groupby
dtc_too_clean_df.groupby(['Type of Ownership']).agg({'DTC Risk-Standardized Rate':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (18, 12))
sns.boxplot(data=dtc_too_clean_df, x='DTC Risk-Standardized Rate', 
            y='Type of Ownership', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('DTC Risk-Standardized Rate (%)', size = 25, fontweight = 'bold')
plt.ylabel('Type of Ownership', size = 25, fontweight = 'bold')
plt.title('Discharge to Community (DTC) Risk-Standardized Rate \n by Type of Ownership', size = 27, fontweight = 'bold')

# %% [markdown]
# ### Potentially Preventable 30-Day Post Discharge Readmission (PPR) Risk-Standardized Rate

# %%
# Create the ppr_nat_df DataFrame.
ppr_nat_df = df[['PPR Risk-Standardized Rate']].copy()
ppr_nat_df.head().style.set_properties(**{'text-align': 'right'})

# %%
ppr_nat_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
ppr_nat_clean_df = ppr_nat_df.dropna()
ppr_nat_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (25, 6))
sns.boxplot(data=ppr_nat_clean_df, x='PPR Risk-Standardized Rate', 
            palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('PPR Risk-Standardized Rate (%)', size = 25, fontweight = 'bold')
plt.ylabel('National', size = 25, fontweight = 'bold')
plt.title('National:  Potentially Preventable 30-Day Post Discharge Readmission (PPR) Risk-Standardized Rate', size = 27, fontweight = 'bold')

# %%
# Create the ppr_state_df DataFrame.
ppr_state_df = df[['State',
                    'PPR Risk-Standardized Rate']].copy()
ppr_state_df.head().style.set_properties(**{'text-align': 'right'})

# %%
ppr_state_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
ppr_state_clean_df = ppr_state_df.dropna()
ppr_state_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
# Create a ppr_state_clean_df summary using .groupby
ppr_state_clean_df.groupby(['State']).agg({'PPR Risk-Standardized Rate':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
# Create a ppr_state_clean_df summary using .groupby
ppr_state_clean_df.groupby(['State']).agg({'PPR Risk-Standardized Rate':['count', 'mean', 'median', 'min', 'max']}).reset_index().tail(27).style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (20, 30))
sns.boxplot(data=ppr_state_clean_df, x='PPR Risk-Standardized Rate', 
            y='State', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('PPR Risk-Standardized Rate (%)', size = 25, fontweight = 'bold')
plt.ylabel('State/Territory', size = 25, fontweight = 'bold')
plt.title('Potentially Preventable 30-Day Post Discharge Readmission (PPR) \n Risk-Standardized Rate by State/Territory', size = 27, fontweight = 'bold')

# %%
# Create the ppr_too_df DataFrame.
ppr_too_df = df[['Type of Ownership',
                    'PPR Risk-Standardized Rate']].copy()
ppr_too_df.head().style.set_properties(**{'text-align': 'right'})

# %%
ppr_too_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
ppr_too_clean_df = ppr_too_df.dropna()
ppr_too_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
ppr_too_clean_df.shape

# %%
ppr_too_clean_df = ppr_too_clean_df.loc[(ppr_too_clean_df['Type of Ownership'] != '-')]
ppr_too_clean_df.shape

# %%
# Create a ppr_too_clean_df summary using .groupby
ppr_too_clean_df.groupby(['Type of Ownership']).agg({'PPR Risk-Standardized Rate':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (18, 12))
sns.boxplot(data=ppr_too_clean_df, x='PPR Risk-Standardized Rate', 
            y='Type of Ownership', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('PPR Risk-Standardized Rate (%)', size = 25, fontweight = 'bold')
plt.ylabel('Type of Ownership', size = 25, fontweight = 'bold')
plt.title('Potentially Preventable 30-Day Post Discharge Readmission (PPR) \n Risk-Standardized Rate by Type of Ownership', size = 27, fontweight = 'bold')

# %% [markdown]
# ### Medicare Spending

# %%
# Create the medicare_spend_nat_df DataFrame.
medicare_spend_nat_df = df[['How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally']].copy()
medicare_spend_nat_df.head().style.set_properties(**{'text-align': 'right'})

# %%
medicare_spend_nat_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
medicare_spend_nat_clean_df = medicare_spend_nat_df.dropna()
medicare_spend_nat_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (25, 6))
sns.boxplot(data=medicare_spend_nat_clean_df, x='How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally', 
            palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Medicare Spend on an Episode of Care', size = 25, fontweight = 'bold')
plt.ylabel('National', size = 25, fontweight = 'bold')
plt.title('National:  How Much Medicare Spends on an Episode of Care', size = 27, fontweight = 'bold')

# %%
# Create the medicare_spend_state_df DataFrame.
medicare_spend_state_df = df[['State',
                    'How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally']].copy()
medicare_spend_state_df.head().style.set_properties(**{'text-align': 'right'})

# %%
medicare_spend_state_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
medicare_spend_state_clean_df = medicare_spend_state_df.dropna()
medicare_spend_state_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
# Create a medicare_spend_state_clean_df summary using .groupby
medicare_spend_state_clean_df.groupby(['State']).agg({'How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
# Create a medicare_spend_state_clean_df summary using .groupby
medicare_spend_state_clean_df.groupby(['State']).agg({'How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally':['count', 'mean', 'median', 'min', 'max']}).reset_index().tail(27).style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (20, 30))
sns.boxplot(data=medicare_spend_state_clean_df, x='How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally', 
            y='State', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Medicare Spend on an Episode of Care', size = 25, fontweight = 'bold')
plt.ylabel('State/Territory', size = 25, fontweight = 'bold')
plt.title('How Much Medicare Spends on an Episode of Care \n by State/Territory', size = 27, fontweight = 'bold')

# %%
# Create the medicare_spend_too_df DataFrame.
medicare_spend_too_df = df[['Type of Ownership',
                    'How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally']].copy()
medicare_spend_too_df.head().style.set_properties(**{'text-align': 'right'})

# %%
medicare_spend_too_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
medicare_spend_too_clean_df = medicare_spend_too_df.dropna()
medicare_spend_too_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
# Create a medicare_spend_too_clean_df summary using .groupby
medicare_spend_too_clean_df.groupby(['Type of Ownership']).agg({'How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (18, 12))
sns.boxplot(data=medicare_spend_too_clean_df, x='How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally', 
            y='Type of Ownership', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Medicare Spend on an Episode of Care', size = 25, fontweight = 'bold')
plt.ylabel('Type of Ownership', size = 25, fontweight = 'bold')
plt.title('How Much Medicare Spends on an Episode of Care \n by Type of Ownership', size = 27, fontweight = 'bold')

# %% [markdown]
# ## Patient Survey Star Rating Analysis
#
# ### Patient Survey Star Rating Measures (4)
# * Care of patients
# * Communication between provider and patients
# * Specific care issues
# * Overall rating of care provided by the home health agency

# %%
ps_df = pd.read_csv('Resources/HHCAHPS_Provider_Jan2023.csv')

# %%
# Set the below parameters so that all rows and columns would be visible
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Calculate the number of rows and columns in the dataset
ps_df.shape

# %%
ps_df.head().style.set_properties(**{'text-align': 'right'})

# %%
ps_df.tail().style.set_properties(**{'text-align': 'right'})

# %% [markdown]
# ### Remove cells that will not be related to further analysis

# %%
columns_to_drop = ['HHCAHPS Survey Summary Star Rating Footnote',
                   'Footnote for Star Rating for gave care in a professional way',
                   'Footnote for Percent of patients who reported that their home health team gave care in a professional way',
                   'Footnote for Star Rating for communicated well with them',
                   'Footnote for Percent of patients who reported that their home health team communicated well with them',
                   'Footnote Star Rating discussed medicines, pain, home safety',
                   'Footnote for Percent of patients who reported that their home health team discussed medicines, pain, and home safety with them',
                   'Footnote for Star Rating for overall care from agency',
                   'Footnote for Percent of patients who gave their home health agency a rating of 9 or 10 on a scale from 0(lowest) to 10(highest)',
                   'Footnote for Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family',
                   'Footnote for number of completed surveys',
                   'Footnote for response rate',
                   'Footnote Number']

ps_df.drop(columns = columns_to_drop, inplace = True)

# %%
ps_df.shape

# %%
ps_df.head().style.set_properties(**{'text-align': 'right'})

# %%
ps_df.tail().style.set_properties(**{'text-align': 'right'})

# %%
ps_df.describe()

# %% [markdown]
# ### Prepare Quality Star Rating DataFrame for join with Patient Survey Star Rating DataFrame

# %%
df.head().style.set_properties(**{'text-align': 'right'})

# %%
qsr_df = df.sort_values(by=['CMS Certification Number (CCN)'])
qsr_df.head()

# %%
columns_to_drop = ['Address',
                  'City',
                  'ZIP',
                  'Phone',
                  'Offers Nursing Care Services',
                  'Offers Physical Therapy Services',
                  'Offers Occupational Therapy Services',
                  'Offers Speech Pathology Services',
                  'Offers Medical Social Services',
                  'Offers Home Health Aide Services',
                  'Date Certified',
                  'Quality of patient care star rating',
                  'How often the home health team began their patients care in a timely manner',
                  'How often the home health team taught patients (or their family caregivers) about their drugs',
                  'How often the home health team determined whether patients received a flu shot for the current flu season',
                  'How often patients got better at walking or moving around',
                  'How often patients got better at getting in and out of bed',
                  'How often patients got better at bathing',
                  'How often patients breathing improved',
                  'How often patients got better at taking their drugs correctly by mouth',
                  'How often home health patients had to be admitted to the hospital',
                  'How often patients receiving home health care needed urgent, unplanned care in the ER without being admitted',
                  'Changes in skin integrity post-acute care: pressure ulcer/injury',
                  'How often physician-recommended actions to address medication issues were completely timely',
                  'Percent of Residents Experiencing One or More Falls with Major Injury',
                  'Application of Percent of Long Term Care Hospital Patients with an Admission and Discharge Functional Assessment and a Care Plan that Addresses Function',
                  'DTC Numerator',
                  'DTC Denominator',
                  'DTC Observed Rate',
                  'DTC Risk-Standardized Rate',
                  'DTC Risk-Standardized Rate (Lower Limit)',
                  'DTC Risk-Standardized Rate (Upper Limit)',
                  'DTC Performance Categorization',
                  'PPR Numerator',
                  'PPR Denominator',
                  'PPR Observed Rate',
                  'PPR Risk-Standardized Rate',
                  'PPR Risk-Standardized Rate (Lower Limit)',
                  'PPR Risk-Standardized Rate (Upper Limit)',
                  'PPR Performance Categorization',
                  'How much Medicare spends on an episode of care at this agency, compared to Medicare spending across all agencies nationally',
                  'No. of episodes to calc how much Medicare spends per episode of care at agency, compared to spending at all agencies (national)']

qsr_df.drop(columns = columns_to_drop, inplace = True)

# %%
qsr_df.shape

# %%
qsr_df.head().style.set_properties(**{'text-align': 'right'})

# %%
qsr_df = qsr_df.reset_index(drop = True)
qsr_df.head().style.set_properties(**{'text-align': 'right'})

# %% [markdown]
# ### Merge Patient Survey DataFrame with Quality DataFrame

# %%
qsr_ps_df = qsr_df.merge(ps_df, how = 'left',
                        left_index = True,
                        right_index = True)
qsr_ps_df.head().style.set_properties(**{'text-align': 'right'})

# %%
columns_to_drop = ['CMS Certification Number (CCN)_y']
qsr_ps_df.drop(columns = columns_to_drop, inplace = True)
qsr_ps_df.head().style.set_properties(**{'text-align': 'right'})

# %%
qsr_ps_df.rename(columns={'CMS Certification Number (CCN)_x': 'CMS Certification Number (CCN)'}, inplace = True)
qsr_ps_df.head().style.set_properties(**{'text-align': 'right'})

# %%
qsr_ps_df.info()

# %%
# Replace string using DataFrame.replace() method.
qsr_ps_df = qsr_ps_df.replace('Not Available',np.nan)
qsr_ps_df.head().style.set_properties(**{'text-align': 'right'})

# %%
# Convert multiple columns to float
qsr_ps_df = qsr_ps_df.astype({'HHCAHPS Survey Summary Star Rating':'float','Star Rating for health team gave care in a professional way':'float',
                             'Percent of patients who reported that their home health team gave care in a professional way':'float',
                             'Star Rating for health team communicated well with them':'float',
                             'Percent of patients who reported that their home health team communicated well with them':'float',
                             'Star Rating team discussed medicines, pain, and home safety':'float',
                             'Percent of patients who reported that their home health team discussed medicines, pain, and home safety with them':'float',
                             'Star Rating for how patients rated overall care from agency':'float',
                             'Percent of patients who gave their home health agency a rating of 9 or 10 on a scale from 0 (lowest) to 10 (highest)':'float',
                             'Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family':'float',
                             'Number of completed Surveys':'float',
                             'Response rate':'float'})
qsr_ps_df.info()

# %%
qsr_ps_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
# Percentage of Medicare certified agencies with patient survey star ratings

percent_agencies_with_ps_star_ratings = 4720/11609
print("Percentage of Medicare certified agencies with patient survey star ratings is {:.2f}%.".format(percent_agencies_with_ps_star_ratings))

# %% [markdown]
# ###  Create Patient Survey Star Rating DataFrame to look at the correlation of patient survey star rating measures to the overall star rating

# %%
columns_to_drop = ['CMS Certification Number (CCN)']
qsr_ps_df.drop(columns = columns_to_drop, inplace = True)

# %%
qsr_ps_corr = qsr_ps_df.corr()
qsr_ps_corr.style.set_properties(**{'text-align': 'right'})

# %%
fig, ax = plt.subplots(figsize = (27, 20))

# Sample figsize in inches

sns.set(font_scale = 2.0)

g = sns.heatmap(qsr_ps_corr, xticklabels = qsr_ps_corr.columns, yticklabels = qsr_ps_corr.columns, 
            annot = True, linewidths = .2, ax = ax, cmap = 'Spectral', annot_kws={'size': 35})
g.set_xticklabels(g.get_xticklabels(), rotation = 50, fontsize = 37, ha = "right")
g.set_yticklabels(g.get_yticklabels(), rotation = 0, fontsize = 37, va = "center")
plt.title('Correlation of Patient Survey Star Rating Measures', fontsize = 50, fontweight = 'bold')

# %%
qsr_ps_df.describe()

# %% [markdown]
# ### Patient Survey Star Rating Distribution

# %%
ps_star_rating = pd.DataFrame(qsr_ps_df['HHCAHPS Survey Summary Star Rating'].value_counts())
ps_star_rating.style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (12, 8))
ax = sns.countplot(x = 'HHCAHPS Survey Summary Star Rating', data = qsr_ps_df, palette = 'Spectral')
ax.bar_label(ax.containers[0], label_type='edge', fontsize = 14, fontweight = 'bold', padding = 3)
plt.xticks(rotation = 0, size = 16)
plt.yticks(size = 16)
plt.xlabel('Patient Survey Star Rating', size = 18, fontweight = 'bold')
plt.ylabel('# of Agencies', size = 18, fontweight = 'bold')
plt.title('HHCAHPS Survey Summary Star Rating Distribution', size = 22, fontweight = 'bold')

# %%
# Create ps_star_rating_nat_df DataFrame.
ps_star_rating_nat_df = qsr_ps_df[['HHCAHPS Survey Summary Star Rating']].copy()
ps_star_rating_nat_df.head()

# %%
ps_star_rating_nat_df.describe()

# %%
ps_star_rating_nat_clean_df = ps_star_rating_nat_df.dropna()
ps_star_rating_nat_clean_df.describe()

# %%
plt.figure(figsize = (25, 6))
sns.boxplot(data=ps_star_rating_nat_clean_df, x='HHCAHPS Survey Summary Star Rating', 
            palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Patient Survey Star Rating', size = 25, fontweight = 'bold')
plt.ylabel('National', size = 25, fontweight = 'bold')
plt.title('National:  HHCAHPS Survey Summary Star Rating', size = 27, fontweight = 'bold')

# %%
# Create ps_star_rating_state_df DataFrame.
ps_star_rating_state_df = qsr_ps_df[['State',
                    'HHCAHPS Survey Summary Star Rating']].copy()
ps_star_rating_state_df.head()

# %%
ps_star_rating_state_df.describe()

# %%
ps_star_rating_state_clean_df = ps_star_rating_state_df.dropna()
ps_star_rating_state_clean_df.describe()

# %%
# Create a State summary by using .groupby
ps_star_rating_state_clean_df.groupby(['State']).agg({'HHCAHPS Survey Summary Star Rating':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
# Create a State summary by using .groupby
ps_star_rating_state_clean_df.groupby(['State']).agg({'HHCAHPS Survey Summary Star Rating':['count', 'mean', 'median', 'min', 'max']}).reset_index().tail(26).style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (20, 30))
sns.boxplot(data=ps_star_rating_state_clean_df, x='HHCAHPS Survey Summary Star Rating', 
            y='State', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Patient Survey Star Rating', size = 25, fontweight = 'bold')
plt.ylabel('State/Territory', size = 25, fontweight = 'bold')
plt.title('HHCAHPS Survey Summary Star Rating \n by State/Territory', size = 27, fontweight = 'bold')

# %%
# Create the ps_star_rating_too_df DataFrame.
ps_star_rating_too_df = qsr_ps_df[['Type of Ownership',
                               'HHCAHPS Survey Summary Star Rating', 
                               'Star Rating for health team gave care in a professional way',
                               'Percent of patients who reported that their home health team gave care in a professional way',
                               'Star Rating for health team communicated well with them',
                               'Percent of patients who reported that their home health team communicated well with them',
                               'Star Rating team discussed medicines, pain, and home safety',
                               'Percent of patients who reported that their home health team discussed medicines, pain, and home safety with them',
                               'Star Rating for how patients rated overall care from agency',
                               'Percent of patients who gave their home health agency a rating of 9 or 10 on a scale from 0 (lowest) to 10 (highest)',
                               'Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family',
                               'Number of completed Surveys',
                               'Response rate']].copy()
ps_star_rating_too_df.head().style.set_properties(**{'text-align': 'right'})

# %%
ps_star_rating_too_df.tail().style.set_properties(**{'text-align': 'right'})

# %%
ps_star_rating_too_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
ps_star_rating_too_clean_df = ps_star_rating_too_df.dropna()
ps_star_rating_too_clean_df = ps_star_rating_too_clean_df.loc[(ps_star_rating_too_clean_df['Type of Ownership'] != '-')]
ps_star_rating_too_clean_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
# Create ps_star_rating__only_too_clean_df DataFrame.
ps_star_rating_only_too_clean_df = ps_star_rating_too_clean_df[['Type of Ownership',
                    'HHCAHPS Survey Summary Star Rating']].copy()
ps_star_rating_only_too_clean_df.head().style.set_properties(**{'text-align': 'right'})

# %%
# Total of ownership type for each type
ps_total_ownership_type_by_type = ps_star_rating_too_clean_df.groupby(['Type of Ownership']).count()['HHCAHPS Survey Summary Star Rating']
ps_total_ownership_type_by_type

# %%
# Create a Type of Ownership summary using .groupby
ps_star_rating_too_clean_df.groupby(['Type of Ownership']).agg({'HHCAHPS Survey Summary Star Rating':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (18, 12))
sns.boxplot(data=ps_star_rating_only_too_clean_df, x='HHCAHPS Survey Summary Star Rating', 
            y='Type of Ownership', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Patient Survey Star Rating', size = 25, fontweight = 'bold')
plt.ylabel('Type of Ownership', size = 25, fontweight = 'bold')
plt.title('HHCAHPS Survey Summary Star Rating \n by Type of Ownership', size = 27, fontweight = 'bold')

# %%
# Create a Type of Ownership DataFrame for each type

ps_gov_combo_df = ps_star_rating_too_clean_df[ps_star_rating_too_clean_df["Type of Ownership"] == 'GOVERNMENT - COMBINATION GOVT & VOLUNTARY']

ps_gov_loc_df = ps_star_rating_too_clean_df[ps_star_rating_too_clean_df["Type of Ownership"] == 'GOVERNMENT - LOCAL']

ps_gov_state_county_df = ps_star_rating_too_clean_df[ps_star_rating_too_clean_df["Type of Ownership"] == 'GOVERNMENT - STATE/COUNTY']

ps_prop_df = ps_star_rating_too_clean_df[ps_star_rating_too_clean_df["Type of Ownership"] == 'PROPRIETARY']

ps_vol_non_prof_rel_df = ps_star_rating_too_clean_df[ps_star_rating_too_clean_df["Type of Ownership"] == 'VOLUNTARY NON PROFIT - RELIGIOUS AFFILIATION']

ps_vol_non_prof_other_df = ps_star_rating_too_clean_df[ps_star_rating_too_clean_df["Type of Ownership"] == 'VOLUNTARY NON-PROFIT - OTHER']

ps_vol_non_prof_priv_df = ps_star_rating_too_clean_df[ps_star_rating_too_clean_df["Type of Ownership"] == 'VOLUNTARY NON-PROFIT - PRIVATE']

# %%
ps_gov_combo_df.head().style.set_properties(**{'text-align': 'right'})

# %%
ps_gov_combo_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
ps_gov_combo_star_rating = pd.DataFrame(ps_gov_combo_df['HHCAHPS Survey Summary Star Rating'].value_counts())
ps_gov_combo_star_rating.style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (12, 8))
ax = sns.countplot(x = 'HHCAHPS Survey Summary Star Rating', data = ps_gov_combo_df, palette = 'Spectral')
ax.bar_label(ax.containers[0], label_type='edge', fontsize = 14, fontweight = 'bold', padding = 3)
plt.xticks(rotation = 0, size = 16)
plt.yticks(size = 16)
plt.xlabel('Patient Survey Star Rating', size = 18, fontweight = 'bold')
plt.ylabel('# of Agencies', size = 18, fontweight = 'bold')
plt.title('Government Combination \n HHCAHPS Survey Summary Star Rating Distribution', size = 22, fontweight = 'bold')

# %%
ps_gov_loc_df.head().style.set_properties(**{'text-align': 'right'})

# %%
ps_gov_loc_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
ps_gov_loc_star_rating = pd.DataFrame(ps_gov_loc_df['HHCAHPS Survey Summary Star Rating'].value_counts())
ps_gov_loc_star_rating.style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (12, 8))
ax = sns.countplot(x = 'HHCAHPS Survey Summary Star Rating', data = ps_gov_loc_df, palette = 'Spectral')
ax.bar_label(ax.containers[0], label_type='edge', fontsize = 14, fontweight = 'bold', padding = 3)
plt.xticks(rotation = 0, size = 16)
plt.yticks(size = 16)
plt.xlabel('Patient Survey Star Rating', size = 18, fontweight = 'bold')
plt.ylabel('# of Agencies', size = 18, fontweight = 'bold')
plt.title('Government Local \n HHCAHPS Survey Summary Star Rating Distribution', size = 22, fontweight = 'bold')

# %%
ps_gov_state_county_df.head().style.set_properties(**{'text-align': 'right'})

# %%
ps_gov_state_county_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
ps_gov_state_county_star_rating = pd.DataFrame(ps_gov_state_county_df['HHCAHPS Survey Summary Star Rating'].value_counts())
ps_gov_state_county_star_rating.style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (12, 8))
ax = sns.countplot(x = 'HHCAHPS Survey Summary Star Rating', data = ps_gov_state_county_df, palette = 'Spectral')
ax.bar_label(ax.containers[0], label_type='edge', fontsize = 14, fontweight = 'bold', padding = 3)
plt.xticks(rotation = 0, size = 16)
plt.yticks(size = 16)
plt.xlabel('Patient Survey Star Rating', size = 18, fontweight = 'bold')
plt.ylabel('# of Agencies', size = 18, fontweight = 'bold')
plt.title('Government State/County \n HHCAHPS Survey Summary Star Rating Distribution', size = 22, fontweight = 'bold')

# %%
ps_prop_df.head().style.set_properties(**{'text-align': 'right'})

# %%
ps_prop_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
ps_prop_star_rating = pd.DataFrame(ps_prop_df['HHCAHPS Survey Summary Star Rating'].value_counts())
ps_prop_star_rating.style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (12, 8))
ax = sns.countplot(x = 'HHCAHPS Survey Summary Star Rating', data = ps_prop_df, palette = 'Spectral')
ax.bar_label(ax.containers[0], label_type='edge', fontsize = 14, fontweight = 'bold', padding = 3)
plt.xticks(rotation = 0, size = 16)
plt.yticks(size = 16)
plt.xlabel('Patient Survey Star Rating', size = 18, fontweight = 'bold')
plt.ylabel('# of Agencies', size = 18, fontweight = 'bold')
plt.title('Proprietary \n HHCAHPS Survey Summary Star Rating Distribution', size = 22, fontweight = 'bold')

# %%
ps_vol_non_prof_rel_df.head().style.set_properties(**{'text-align': 'right'})

# %%
ps_vol_non_prof_rel_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
ps_vol_non_prof_rel_star_rating = pd.DataFrame(ps_vol_non_prof_rel_df['HHCAHPS Survey Summary Star Rating'].value_counts())
ps_vol_non_prof_rel_star_rating.style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (12, 8))
ax = sns.countplot(x = 'HHCAHPS Survey Summary Star Rating', data = ps_vol_non_prof_rel_df, palette = 'Spectral')
ax.bar_label(ax.containers[0], label_type='edge', fontsize = 14, fontweight = 'bold', padding = 3)
plt.xticks(rotation = 0, size = 16)
plt.yticks(size = 16)
plt.xlabel('Patient Survey Star Rating', size = 18, fontweight = 'bold')
plt.ylabel('# of Agencies', size = 18, fontweight = 'bold')
plt.title('Voluntary Non-Profit Religious \n HHCAHPS Survey Summary Star Rating Distribution', size = 22, fontweight = 'bold')

# %%
ps_vol_non_prof_other_df.head().style.set_properties(**{'text-align': 'right'})

# %%
ps_vol_non_prof_other_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
ps_vol_non_prof_other_star_rating = pd.DataFrame(ps_vol_non_prof_other_df['HHCAHPS Survey Summary Star Rating'].value_counts())
ps_vol_non_prof_other_star_rating.style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (12, 8))
ax = sns.countplot(x = 'HHCAHPS Survey Summary Star Rating', data = ps_vol_non_prof_other_df, palette = 'Spectral')
ax.bar_label(ax.containers[0], label_type='edge', fontsize = 14, fontweight = 'bold', padding = 3)
plt.xticks(rotation = 0, size = 16)
plt.yticks(size = 16)
plt.xlabel('Patient Survey Star Rating', size = 18, fontweight = 'bold')
plt.ylabel('# of Agencies', size = 18, fontweight = 'bold')
plt.title('Voluntary Non-Profit Other \n HHCAHPS Survey Summary Star Rating Distribution', size = 22, fontweight = 'bold')

# %%
ps_vol_non_prof_priv_df.head().style.set_properties(**{'text-align': 'right'})

# %%
ps_vol_non_prof_priv_df.describe().style.set_properties(**{'text-align': 'right'})

# %%
ps_vol_non_prof_priv_star_rating = pd.DataFrame(ps_vol_non_prof_priv_df['HHCAHPS Survey Summary Star Rating'].value_counts())
ps_vol_non_prof_priv_star_rating.style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (12, 8))
ax = sns.countplot(x = 'HHCAHPS Survey Summary Star Rating', data = ps_vol_non_prof_priv_df, palette = 'Spectral')
ax.bar_label(ax.containers[0], label_type='edge', fontsize = 14, fontweight = 'bold', padding = 3)
plt.xticks(rotation = 0, size = 16)
plt.yticks(size = 16)
plt.xlabel('Patient Survey Star Rating', size = 18, fontweight = 'bold')
plt.ylabel('# of Agencies', size = 18, fontweight = 'bold')
plt.title('Voluntary Non-Profit Private \n HHCAHPS Survey Summary Star Rating Distribution', size = 22, fontweight = 'bold')

# %% [markdown]
# ### Patient Survey Star Rating Willingness to Recommend

# %%
# Create ps_star_rating_nat_df DataFrame.
ps_wtr_nat_df = qsr_ps_df[['Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family']].copy()
ps_wtr_nat_df.head()

# %%
ps_wtr_nat_df.describe()

# %%
ps_wtr_nat_clean_df = ps_wtr_nat_df.dropna()
ps_wtr_nat_clean_df.describe()

# %%
plt.figure(figsize = (25, 6))
sns.boxplot(data=ps_wtr_nat_clean_df, x='Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family', 
            palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Willingness to Recommend (%)', size = 25, fontweight = 'bold')
plt.ylabel('National', size = 25, fontweight = 'bold')
plt.title('National:  HHCAHPS Survey Willingness to Recommend (%)', size = 27, fontweight = 'bold')

# %%
# Create ps_wtr_state_df DataFrame.
ps_wtr_state_df = qsr_ps_df[['State',
                    'Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family']].copy()
ps_wtr_state_df.head()

# %%
ps_wtr_state_df.describe()

# %%
ps_wtr_state_clean_df = ps_wtr_state_df.dropna()
ps_wtr_state_clean_df.describe()

# %%
# Create a State summary by using .groupby
ps_wtr_state_clean_df.groupby(['State']).agg({'Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
# Create a State summary by using .groupby
ps_wtr_state_clean_df.groupby(['State']).agg({'Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family':['count', 'mean', 'median', 'min', 'max']}).reset_index().tail(27).style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (20, 30))
sns.boxplot(data=ps_wtr_state_clean_df, x='Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family', 
            y='State', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Willingness to Recommend (%)', size = 25, fontweight = 'bold')
plt.ylabel('State/Territory', size = 25, fontweight = 'bold')
plt.title('HHCAHPS Survey Willingness to Recommend (%) \n by State/Territory', size = 27, fontweight = 'bold')

# %%
# Create ps_wtr__only_too_clean_df DataFrame.
ps_wtr_only_too_clean_df = ps_star_rating_too_clean_df[['Type of Ownership',
                    'Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family']].copy()
ps_wtr_only_too_clean_df.head().style.set_properties(**{'text-align': 'right'})

# %%
# Total of ownership type for each type
ps_wtr_total_ownership_type_by_type = ps_wtr_only_too_clean_df.groupby(['Type of Ownership']).count()['Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family']
ps_wtr_total_ownership_type_by_type

# %%
# Create a Type of Ownership summary using .groupby
ps_wtr_only_too_clean_df.groupby(['Type of Ownership']).agg({'Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (18, 12))
sns.boxplot(data=ps_wtr_only_too_clean_df, x='Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family', 
            y='Type of Ownership', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Willingness to Recommend (%)', size = 25, fontweight = 'bold')
plt.ylabel('Type of Ownership', size = 25, fontweight = 'bold')
plt.title('HHCAHPS Survey Willingness to Recommend (%) \n by Type of Ownership', size = 27, fontweight = 'bold')

# %% [markdown]
# ### Patient Survey Star Rating Response Rate

# %%
# Create ps_rr_nat_df DataFrame.
ps_rr_nat_df = qsr_ps_df[['Response rate']].copy()
ps_rr_nat_df.head()

# %%
ps_rr_nat_df.describe()

# %%
ps_rr_nat_clean_df = ps_rr_nat_df.dropna()
ps_rr_nat_clean_df.describe()

# %%
plt.figure(figsize = (25, 6))
sns.boxplot(data=ps_rr_nat_clean_df, x='Response rate', 
            palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Response Rate (%)', size = 25, fontweight = 'bold')
plt.ylabel('National', size = 25, fontweight = 'bold')
plt.title('National:  HHCAHPS Survey Response Rate (%)', size = 27, fontweight = 'bold')

# %%
# Create ps_rr_state_df DataFrame.
ps_rr_state_df = qsr_ps_df[['State',
                    'Response rate']].copy()
ps_rr_state_df.head()

# %%
ps_rr_state_df.describe()

# %%
ps_rr_state_clean_df = ps_rr_state_df.dropna()
ps_rr_state_clean_df.describe()

# %%
# Create a State summary by using .groupby
ps_rr_state_clean_df.groupby(['State']).agg({'Response rate':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
# Create a State summary by using .groupby (tail(27))
ps_rr_state_clean_df.groupby(['State']).agg({'Response rate':['count', 'mean', 'median', 'min', 'max']}).reset_index().tail(27).style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (20, 30))
sns.boxplot(data=ps_rr_state_clean_df, x='Response rate', 
            y='State', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Response Rate (%)', size = 25, fontweight = 'bold')
plt.ylabel('State/Territory', size = 25, fontweight = 'bold')
plt.title('HHCAHPS Survey Response Rate (%) \n by State/Territory', size = 27, fontweight = 'bold')

# %%
# Create ps_rr__only_too_clean_df DataFrame.
ps_rr_only_too_clean_df = ps_star_rating_too_clean_df[['Type of Ownership',
                    'Response rate']].copy()
ps_rr_only_too_clean_df.head().style.set_properties(**{'text-align': 'right'})

# %%
# Total of ownership type for each type
ps_rr_total_ownership_type_by_type = ps_rr_only_too_clean_df.groupby(['Type of Ownership']).count()['Response rate']
ps_rr_total_ownership_type_by_type

# %%
# Create a Type of Ownership summary using .groupby
ps_rr_only_too_clean_df.groupby(['Type of Ownership']).agg({'Response rate':['count', 'mean', 'median', 'min', 'max']}).reset_index().style.set_properties(**{'text-align': 'right'})

# %%
plt.figure(figsize = (18, 12))
sns.boxplot(data=ps_rr_only_too_clean_df, x='Response rate', 
            y='Type of Ownership', palette = 'Spectral')
plt.xticks(rotation = 0, size = 18)
plt.yticks(size = 18)
plt.xlabel('Response Rate (%)', size = 25, fontweight = 'bold')
plt.ylabel('Type of Ownership', size = 25, fontweight = 'bold')
plt.title('HHCAHPS Survey Response Rate (%) \n by Type of Ownership', size = 27, fontweight = 'bold')
